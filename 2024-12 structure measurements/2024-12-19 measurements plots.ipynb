# %% [markdown]
# # Plotting the measurements of the dataset
# 2024-12-19

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# %%
dataAF = pd.read_csv(Path("output/af_structures.csv"))
dataSolved = pd.read_csv(Path("output/solved_structures.csv"))
predictionAF = pd.read_excel(Path("../ressources/ISS AF_DMI_structures/AF_prediction_randomized_DMI_results.xlsx"))

_dataAF = pd.merge(
    left=dataAF, 
    right=predictionAF,
    how='left',
    left_on=['structure_name', 'file'],
    right_on=['prediction_name', 'model_id'],
)
_dataAF = _dataAF.replace({np.nan: None})
dataAF = _dataAF[[*dataAF.columns, "num_mutation_in_motif"]]

# %%
predictionAF

# %%
dataAF
# Out:
#               structure_name      file  hbonds  salt_bridges  buried_area  \
# 0     DEG_APCC_KENBOX_2_4GGD  ranked_0       9             0      688.863
# 1     DEG_APCC_KENBOX_2_4GGD  ranked_1       9             0      648.414
# 2     DEG_APCC_KENBOX_2_4GGD  ranked_2      10             0      724.694
# 3     DEG_APCC_KENBOX_2_4GGD  ranked_3       2             0      450.095
# 4     DEG_APCC_KENBOX_2_4GGD  ranked_4       2             0      359.838
# ...                      ...       ...     ...           ...          ...
# 1337           TRG_PTS1_2C0L  ranked_0      12             3      915.859
# 1338           TRG_PTS1_2C0L  ranked_1      11             3      933.190
# 1339           TRG_PTS1_2C0L  ranked_2      12             3      932.483
# 1340           TRG_PTS1_2C0L  ranked_3      11             3      930.683
# 1341           TRG_PTS1_2C0L  ranked_4      12             3      942.776
#
#       min_distance  hydrophobic_interactions num_mutation_in_motif
# 0         6.063404                         0         known minimal
# 1         6.083082                         0         known minimal
# 2         6.072073                         3         known minimal
# 3         5.417125                         0         known minimal
# 4         5.091792                         9         known minimal
# ...            ...                       ...                   ...
# 1337      4.542064                        29         known minimal
# 1338      4.558981                        29         known minimal
# 1339      4.574167                        30         known minimal
# 1340      4.528674                        30         known minimal
# 1341      4.567587                        27         known minimal
#
# [1342 rows x 8 columns]

# %%
dataSolved
# Out:
#     structure_name              file  hbonds  salt_bridges  buried_area  \
# 0     1ATP_min_DMI  1ATP_min_DMI.pdb       1             0      872.216
# 1     1AXC_min_DMI  1AXC_min_DMI.pdb       4             0     1276.554
# 2     1B72_min_DMI  1B72_min_DMI.pdb       1             0      585.041
# 3     1B8Q_min_DMI  1B8Q_min_DMI.pdb       4             0      928.705
# 4     1BXX_min_DMI  1BXX_min_DMI.pdb       6             0      818.831
# ..             ...               ...     ...           ...          ...
# 133   5MLW_min_DMI  5MLW_min_DMI.pdb       2             0     1024.182
# 134   5VZU_min_DMI  5VZU_min_DMI.pdb       4             0      877.551
# 135   6FUZ_min_DMI  6FUZ_min_DMI.pdb      10             3     1123.307
# 136   6G84_min_DMI  6G84_min_DMI.pdb       4             0     1254.304
# 137   7DS2_min_DMI  7DS2_min_DMI.pdb       8             6     1627.789
#
#      min_distance  hydrophobic_interactions
# 0        6.273099                        77
# 1        4.173686                        62
# 2        5.182325                        36
# 3        4.376202                        42
# 4        4.435122                        19
# ..            ...                       ...
# 133      4.282367                       114
# 134      4.959148                        33
# 135      5.531992                         2
# 136      5.521322                        35
# 137      5.075359                        51
#
# [138 rows x 7 columns]

# %%
print(set(dataAF["num_mutation_in_motif"]))
# Out:
# {'known minimal', None}

# %%
def plotCummulative(column, title, ylabel, xlabel):
    plt.title(title)
    d = dataAF[column]
    plt.ecdf(d, color="green")
    #plt.vlines(np.median(d), ymin=0, ymax=1, label="median", colors="green", linestyles="dashed")
    plt.vlines(np.mean(d), ymin=0, ymax=1, label="mean AF", colors="green", linestyles="dotted")
    d = dataSolved[column]
    plt.ecdf(d, color="orange")
    #plt.vlines(np.median(d), ymin=0, ymax=1, label="median", colors="orange", linestyles="dashed")
    plt.vlines(np.mean(d), ymin=0, ymax=1, label="mean Solved", colors="orange", linestyles="dotted")
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.legend()
    plt.show()
plotCummulative("hbonds", "hydrogen bonds", "cummulative percentile", "count of hydrogen bonds")
plotCummulative("salt_bridges", "salt bridges", "cummulative percentile", "count of hydrogen bonds")
plotCummulative("buried_area", "surface area", "cummulative percentile", "area [Å²]")
plotCummulative("min_distance", "minimum interface distance ", "cummulative percentile", "distance [Å]")
plotCummulative("hydrophobic_interactions", "hydrophobic interactions", "cummulative percentile", "count")

# %%
def plotCummulative(column, title, ylabel, xlabel):
    fig, axes = plt.subplots(1, 2)
    fig.set_figwidth(13)
    for i, d in enumerate([dataAF[column], dataSolved[column]]):
        ax = axes[i]
        ax.set_title(title)
        ax.ecdf(d)
        ax.vlines(np.median(d), ymin=0, ymax=1, label="median", colors="grey", linestyles="dashed")
        ax.vlines(np.mean(d), ymin=0, ymax=1, label="mean", colors="grey", linestyles="dotted")
        ax.set_ylabel(ylabel)
        ax.set_xlabel(xlabel)
        ax.legend()
    plt.show()

# %%
plotCummulative("hbonds", "hydrogen bonds", "cummulative percentile", "count of hydrogen bonds")

# %%
d = data["hbonds"]
plt.title("hydrogen bonds")
plt.ecdf(d)
plt.vlines(np.median(d), ymin=0, ymax=1, label="median", colors="grey", linestyles="dashed")
plt.vlines(np.mean(d), ymin=0, ymax=1, label="mean", colors="grey", linestyles="dotted")
plt.ylabel("cummulative percentile")
plt.xlabel("count")
plt.legend()
plt.show()

# %%
d = data["salt_bridges"]
plt.title("salt bridges")
plt.ecdf(d)
plt.vlines(np.median(d), ymin=0, ymax=1, label="median", colors="grey", linestyles="dashed")
plt.vlines(np.mean(d), ymin=0, ymax=1, label="mean", colors="grey", linestyles="dotted")
plt.ylabel("cummulative percentile")
plt.xlabel("count")
plt.legend()
plt.show()

# %%
d = data["buried_area"]
plt.title("surface area")
plt.ecdf(d)
plt.vlines(np.median(d), ymin=0, ymax=1, label="median", colors="grey", linestyles="dashed")
plt.vlines(np.mean(d), ymin=0, ymax=1, label="mean", colors="grey", linestyles="dotted")
plt.ylabel("cummulative percentile")
plt.xlabel("area [Å²]")
plt.legend()
plt.show()

# %%
d = data["min_distance"]
plt.title("minimum interface distance")
plt.ecdf(d)
plt.vlines(np.median(d), ymin=0, ymax=1, label="median", colors="grey", linestyles="dashed")
plt.vlines(np.mean(d), ymin=0, ymax=1, label="mean", colors="grey", linestyles="dotted")
plt.ylabel("cummulative percentile")
plt.xlabel("distance [Å]")
plt.legend()
plt.show()

# %%
d = data["hydrophobic_interactions"]
plt.title("hydrophobic interactions")
plt.ecdf(d)
plt.vlines(np.median(d), ymin=0, ymax=1, label="median", colors="grey", linestyles="dashed")
plt.vlines(np.mean(d), ymin=0, ymax=1, label="mean", colors="grey", linestyles="dotted")
plt.ylabel("cummulative percentile")
plt.xlabel("count")
plt.legend()
plt.show()
