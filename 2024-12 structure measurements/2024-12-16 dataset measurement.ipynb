# %% [markdown]
# # Measure structures
# * Measure .pdb structure files and output csv files
# * Validate data
# * Generate H atoms for solved structures
#
# Notes:
# * Needs dataset_measure.py to run
#
# created 2024-12-16

# %%
import pathlib
import dataset_measure

structure_basePath = pathlib.Path("../ressources/ISS AF_DMI_structures").absolute()
structure_folders = [structure_basePath / p for p in ['AF_DMI_structures1', 'AF_DMI_structures2', 'AF_DMI_structures3']]
solved_basePath = pathlib.Path("../ressources/ISS DMI_solved_structures").absolute()
solvedHydrogen_basePath = pathlib.Path("../ressources/ISS DMI_solved_structures hydrogens").absolute()

pathObj = {}

# %%
def WalkFolder(basePath: str, 
               pathObj:dict[str, dict[str, pathlib.Path]]={},
               structures: None|str|list[str] = None,
               files: None|bool|str|list[str] = None
               ) -> dict[str, dict[str, pathlib.Path]]:
    """
        Add the path basePath/structure/file.pdb to the pathObj provided (or create a new one if omitted).
        If files and/or structures are None, search inside the directory for all pdb files.
        Returns:
            pathObj: dict[name:str, tuple[path: pathlib.Path, structure_name: str]]
    """

    structures_count = 0
    basePath = pathlib.Path(basePath).absolute()
    if not basePath.is_dir():
        raise ValueError("The given basePath is not a valid directory")
    
    if structures is None:
        structures: list[pathlib.Path] = [p for p in basePath.iterdir()]
    elif isinstance(structures, str):
        structures: list[pathlib.Path] = [basePath / structures]
    elif isinstance(structures, list):
        structures: list[pathlib.Path] = [basePath / p for p in structures]
    else:
        raise ValueError("Invalid argument for structures")

    for structure in structures:
        if not structure.exists():
            raise ValueError(f"The structure {structure} does not point to a valid path")
        structure_name = str(structure.name)
        if structure.is_file():
            if structure.suffix.lower() == ".pdb":
                structure_name = str(structure.stem)
                if structure_name in pathObj.keys():
                    raise ValueError(f"Duplicate structure and file {structure}")
                pathObj[structure_name] = (structure.absolute(), structure_name)
                structures_count += 1
            continue

        if files is None:
            filesF: list[pathlib.Path] = [f for f in structure.iterdir() if f.is_file()]
        elif isinstance(files, str):
            filesF: list[pathlib.Path] = [structure / f"{files}.pdb"]
        elif isinstance(files, list):
            filesF: list[pathlib.Path] = [structure / f"{f}.pdb" for f in files]
        else:
            raise ValueError("Invalid argument for files")
        
        for file in filesF:
            if not file.exists() or not file.is_file():
                raise ValueError(f"{structure}/{file} does not point to a valid file")
            if not file.suffix.lower() == ".pdb":
                continue
            file_name = file.stem
            name = f"{structure_name}-{file_name}"
            if name in pathObj.keys():
                raise ValueError(f"Duplicate structure and file {structure}/{file_name}.pdb")
            pathObj[name] = (file.absolute(), structure_name)
            structures_count += 1
    print(f"Found {structures_count} structures")
    return pathObj

# %%
pathObj = {}
for f in structure_folders:
    WalkFolder(f, pathObj)
print("Total structures:", len(pathObj))
# Out:
# Found 400 structures
# Found 525 structures
# Found 445 structures
# Total structures: 1370

# %%
result = dataset_measure.Run(list(pathObj.values()), silent=False)
result
# Out:
#               structure_name          file  hbonds  salt_bridges  buried_area  \
# 0     DEG_APCC_KENBOX_2_4GGD  ranked_0.pdb       9             0      688.863
# 1     DEG_APCC_KENBOX_2_4GGD  ranked_1.pdb       9             0      648.414
# 2     DEG_APCC_KENBOX_2_4GGD  ranked_2.pdb      10             0      724.694
# 3     DEG_APCC_KENBOX_2_4GGD  ranked_3.pdb       2             0      450.095
# 4     DEG_APCC_KENBOX_2_4GGD  ranked_4.pdb       2             0      359.838
# ...                      ...           ...     ...           ...          ...
# 1337           TRG_PTS1_2C0L  ranked_0.pdb      12             3      915.859
# 1338           TRG_PTS1_2C0L  ranked_1.pdb      11             3      933.190
# 1339           TRG_PTS1_2C0L  ranked_2.pdb      12             3      932.483
# 1340           TRG_PTS1_2C0L  ranked_3.pdb      11             3      930.683
# 1341           TRG_PTS1_2C0L  ranked_4.pdb      12             3      942.776
#
#       min_distance  hydrophobic_interactions
# 0         6.063404                         0
# 1         6.083082                         0
# 2         6.072073                         3
# 3         5.417125                         0
# 4         5.091792                         9
# ...            ...                       ...
# 1337      4.542064                        29
# 1338      4.558981                        29
# 1339      4.574167                        30
# 1340      4.528674                        30
# 1341      4.567587                        27
#
# [1342 rows x 7 columns]

# %%
result.to_csv(pathlib.Path("output/af_structures.csv"), index=False)

# %%
pathObj = {}
WalkFolder(solvedHydrogen_basePath, pathObj)
print("Total structures:", len(pathObj))
# Out:
# Found 138 structures
# Total structures: 138

# %%
result = dataset_measure.Run(list(pathObj.values()), silent=False)
result
# Out:
#     structure_name              file  hbonds  salt_bridges  buried_area  \
# 0     1ATP_min_DMI  1ATP_min_DMI.pdb       1             0      872.216
# 1     1AXC_min_DMI  1AXC_min_DMI.pdb       4             0     1276.554
# 2     1B72_min_DMI  1B72_min_DMI.pdb       1             0      585.041
# 3     1B8Q_min_DMI  1B8Q_min_DMI.pdb       4             0      928.705
# 4     1BXX_min_DMI  1BXX_min_DMI.pdb       6             0      818.831
# ..             ...               ...     ...           ...          ...
# 133   5MLW_min_DMI  5MLW_min_DMI.pdb       2             0     1024.182
# 134   5VZU_min_DMI  5VZU_min_DMI.pdb       4             0      877.551
# 135   6FUZ_min_DMI  6FUZ_min_DMI.pdb      10             3     1123.307
# 136   6G84_min_DMI  6G84_min_DMI.pdb       4             0     1254.304
# 137   7DS2_min_DMI  7DS2_min_DMI.pdb       8             6     1627.789
#
#      min_distance  hydrophobic_interactions
# 0        6.273099                        77
# 1        4.173686                        62
# 2        5.182325                        36
# 3        4.376202                        42
# 4        4.435122                        19
# ..            ...                       ...
# 133      4.282367                       114
# 134      4.959148                        33
# 135      5.531992                         2
# 136      5.521322                        35
# 137      5.075359                        51
#
# [138 rows x 7 columns]

# %%
result.to_csv(pathlib.Path("output/solved_structures.csv"), index=False)

# %% [markdown]
# #### Validation
# Validate if my generated data is equal to the data generated on ISS

# %%
import pandas as pd
import pathlib

# %%
issData = pd.read_csv(pathlib.Path("../ISS Code/output/structure_analysis_results_biopython_with_hydrophobic_and_final.csv"))
myData = pd.read_csv(pathlib.Path("output/af_structures.csv"))

# %%
issData
# Out:
#              prediction_name structure_file  hbonds  salt_bridges  \
# 0     DEG_APCC_KENBOX_2_4GGD   ranked_0.pdb       9             0
# 1     DEG_APCC_KENBOX_2_4GGD   ranked_1.pdb       9             0
# 2     DEG_APCC_KENBOX_2_4GGD   ranked_2.pdb      10             0
# 3     DEG_APCC_KENBOX_2_4GGD   ranked_3.pdb       2             0
# 4     DEG_APCC_KENBOX_2_4GGD   ranked_4.pdb       2             0
# ...                      ...            ...     ...           ...
# 1337           TRG_PTS1_2C0L   ranked_0.pdb      12             3
# 1338           TRG_PTS1_2C0L   ranked_1.pdb      11             3
# 1339           TRG_PTS1_2C0L   ranked_2.pdb      12             3
# 1340           TRG_PTS1_2C0L   ranked_3.pdb      11             3
# 1341           TRG_PTS1_2C0L   ranked_4.pdb      12             3
#
#       buried_area  min_distance  hydrophobic_interactions
# 0         688.863      6.063404                         0
# 1         648.414      6.083082                         0
# 2         724.694      6.072073                         3
# 3         450.095      5.417125                         0
# 4         359.838      5.091792                         9
# ...           ...           ...                       ...
# 1337      915.859      4.542064                        29
# 1338      933.190      4.558981                        29
# 1339      932.483      4.574167                        30
# 1340      930.683      4.528673                        30
# 1341      942.776      4.567587                        27
#
# [1342 rows x 7 columns]

# %%
myData
# Out:
#               structure_name          file  hbonds  salt_bridges  buried_area  \
# 0     DEG_APCC_KENBOX_2_4GGD  ranked_0.pdb       9             0      688.863
# 1     DEG_APCC_KENBOX_2_4GGD  ranked_1.pdb       9             0      648.414
# 2     DEG_APCC_KENBOX_2_4GGD  ranked_2.pdb      10             0      724.694
# 3     DEG_APCC_KENBOX_2_4GGD  ranked_3.pdb       2             0      450.095
# 4     DEG_APCC_KENBOX_2_4GGD  ranked_4.pdb       2             0      359.838
# ...                      ...           ...     ...           ...          ...
# 1337           TRG_PTS1_2C0L  ranked_0.pdb      12             3      915.859
# 1338           TRG_PTS1_2C0L  ranked_1.pdb      11             3      933.190
# 1339           TRG_PTS1_2C0L  ranked_2.pdb      12             3      932.483
# 1340           TRG_PTS1_2C0L  ranked_3.pdb      11             3      930.683
# 1341           TRG_PTS1_2C0L  ranked_4.pdb      12             3      942.776
#
#       min_distance  hydrophobic_interactions
# 0         6.063404                         0
# 1         6.083082                         0
# 2         6.072073                         3
# 3         5.417125                         0
# 4         5.091792                         9
# ...            ...                       ...
# 1337      4.542064                        29
# 1338      4.558981                        29
# 1339      4.574167                        30
# 1340      4.528674                        30
# 1341      4.567587                        27
#
# [1342 rows x 7 columns]

# %%
joinedData = pd.merge(
    left=myData, 
    right=issData,
    how='outer',
    left_on=['structure_name', 'file'],
    right_on=['prediction_name', 'structure_file'],
)
joinedData
# Out:
#               structure_name          file  hbonds_x  salt_bridges_x  \
# 0     DEG_APCC_KENBOX_2_4GGD  ranked_0.pdb         9               0
# 1     DEG_APCC_KENBOX_2_4GGD  ranked_1.pdb         9               0
# 2     DEG_APCC_KENBOX_2_4GGD  ranked_2.pdb        10               0
# 3     DEG_APCC_KENBOX_2_4GGD  ranked_3.pdb         2               0
# 4     DEG_APCC_KENBOX_2_4GGD  ranked_4.pdb         2               0
# ...                      ...           ...       ...             ...
# 1337           TRG_PTS1_2C0L  ranked_0.pdb        12               3
# 1338           TRG_PTS1_2C0L  ranked_1.pdb        11               3
# 1339           TRG_PTS1_2C0L  ranked_2.pdb        12               3
# 1340           TRG_PTS1_2C0L  ranked_3.pdb        11               3
# 1341           TRG_PTS1_2C0L  ranked_4.pdb        12               3
#
#       buried_area_x  min_distance_x  hydrophobic_interactions_x  \
# 0           688.863        6.063404                           0
# 1           648.414        6.083082                           0
# 2           724.694        6.072073                           3
# 3           450.095        5.417125                           0
# 4           359.838        5.091792                           9
# ...             ...             ...                         ...
# 1337        915.859        4.542064                          29
# 1338        933.190        4.558981                          29
# 1339        932.483        4.574167                          30
# 1340        930.683        4.528674                          30
# 1341        942.776        4.567587                          27
#
#              prediction_name structure_file  hbonds_y  salt_bridges_y  \
# 0     DEG_APCC_KENBOX_2_4GGD   ranked_0.pdb         9               0
# 1     DEG_APCC_KENBOX_2_4GGD   ranked_1.pdb         9               0
# 2     DEG_APCC_KENBOX_2_4GGD   ranked_2.pdb        10               0
# 3     DEG_APCC_KENBOX_2_4GGD   ranked_3.pdb         2               0
# 4     DEG_APCC_KENBOX_2_4GGD   ranked_4.pdb         2               0
# ...                      ...            ...       ...             ...
# 1337           TRG_PTS1_2C0L   ranked_0.pdb        12               3
# 1338           TRG_PTS1_2C0L   ranked_1.pdb        11               3
# 1339           TRG_PTS1_2C0L   ranked_2.pdb        12               3
# 1340           TRG_PTS1_2C0L   ranked_3.pdb        11               3
# 1341           TRG_PTS1_2C0L   ranked_4.pdb        12               3
#
#       buried_area_y  min_distance_y  hydrophobic_interactions_y
# 0           688.863        6.063404                           0
# 1           648.414        6.083082                           0
# 2           724.694        6.072073                           3
# 3           450.095        5.417125                           0
# 4           359.838        5.091792                           9
# ...             ...             ...                         ...
# 1337        915.859        4.542064                          29
# 1338        933.190        4.558981                          29
# 1339        932.483        4.574167                          30
# 1340        930.683        4.528673                          30
# 1341        942.776        4.567587                          27
#
# [1342 rows x 14 columns]

# %%
column = "hbonds"
divergingRows = joinedData.query(f"({column}_x - {column}_y)**2 >= 0.001")
divergingRows[["structure_name", "file", f"{column}_x",f"{column}_y"]]
# Out:
# Empty DataFrame
# Columns: [structure_name, file, hbonds_x, hbonds_y]
# Index: []

# %%
column = "buried_area"
divergingRows = joinedData.query(f"({column}_x - {column}_y)**2 >= 0.001")
divergingRows[["structure_name", "file", f"{column}_x",f"{column}_y"]]
# Out:
# Empty DataFrame
# Columns: [structure_name, file, buried_area_x, buried_area_y]
# Index: []

# %%
# That one is ok, as there was an error in the original ISS code
column = "salt_bridges"
divergingRows = joinedData.query(f"({column}_x - {column}_y)**2 >= 0.001")
divergingRows[["structure_name", "file", f"{column}_x",f"{column}_y"]]
# Out:
#                  structure_name          file  salt_bridges_x  salt_bridges_y
# 9               DEG_COP1_1_5IGO  ranked_4.pdb               2               0
# 10       DEG_Kelch_Keap1_1_2FLU  ranked_0.pdb              11               0
# 11       DEG_Kelch_Keap1_1_2FLU  ranked_1.pdb               9               0
# 12       DEG_Kelch_Keap1_1_2FLU  ranked_2.pdb              11               0
# 13       DEG_Kelch_Keap1_1_2FLU  ranked_3.pdb               9               0
# ...                         ...           ...             ...             ...
# 1325  TRG_LysEnd_GGAAcLL_1_1JWG  ranked_3.pdb               1               0
# 1327        TRG_NES_CRM1_1_3GB8  ranked_0.pdb               5               0
# 1328        TRG_NES_CRM1_1_3GB8  ranked_1.pdb               3               0
# 1329        TRG_NES_CRM1_1_3GB8  ranked_2.pdb               4               0
# 1330        TRG_NES_CRM1_1_3GB8  ranked_3.pdb               3               0
#
# [277 rows x 4 columns]

# %%
column = "min_distance"
divergingRows = joinedData.query(f"({column}_x - {column}_y)**2 >= 0.001")
divergingRows[["structure_name", "file", f"{column}_x",f"{column}_y"]]
# Out:
#                                       structure_name          file  \
# 335                                LIG_HOMEOBOX_1B72  ranked_0.pdb
# 336                                LIG_HOMEOBOX_1B72  ranked_1.pdb
# 337                                LIG_HOMEOBOX_1B72  ranked_2.pdb
# 338                                LIG_HOMEOBOX_1B72  ranked_3.pdb
# 339                                LIG_HOMEOBOX_1B72  ranked_4.pdb
# 393                               LIG_LYPXL_S_1_2R03  ranked_2.pdb
# 394                               LIG_LYPXL_S_1_2R03  ranked_3.pdb
# 395                               LIG_LYPXL_S_1_2R03  ranked_4.pdb
# 666         MDEG_SPOP_SBC_1_3HQM.DDOC_MIT_MIM_1_2JQ9  ranked_4.pdb
# 767        MDOC_USP7_UBL2_3_4YOC.DTRG_ER_FFAT_1_2RR3  ranked_0.pdb
# 769        MDOC_USP7_UBL2_3_4YOC.DTRG_ER_FFAT_1_2RR3  ranked_2.pdb
# 770        MDOC_USP7_UBL2_3_4YOC.DTRG_ER_FFAT_1_2RR3  ranked_3.pdb
# 771        MDOC_USP7_UBL2_3_4YOC.DTRG_ER_FFAT_1_2RR3  ranked_4.pdb
# 786            MLIG_AP2alpha_1_1KY7.DLIG_PAM2_1_1JGN  ranked_4.pdb
# 799       MLIG_ARL_BART_1_4ZI2.DLIG_LYPXL_SIV_4_2XS1  ranked_2.pdb
# 800       MLIG_ARL_BART_1_4ZI2.DLIG_LYPXL_SIV_4_2XS1  ranked_3.pdb
# 801       MLIG_ARL_BART_1_4ZI2.DLIG_LYPXL_SIV_4_2XS1  ranked_4.pdb
# 832   MLIG_BIR_III_3_1JD5.DLIG_LRP6_Inhibitor_1_3SOQ  ranked_0.pdb
# 901     MLIG_EH1_1_2CE8.DLIG_SH3_CIN85_PxpxPR_1_2BZ8  ranked_4.pdb
# 921           MLIG_EVH1_3_1MKE.DLIG_LSD1_SNAG_1_2Y48  ranked_4.pdb
# 956       MLIG_IBAR_NPY_1_2YKT.DLIG_UFM1_UFIM_1_5HKH  ranked_4.pdb
# 1033  MLIG_NRP_CendR_1_2ORZ.DLIG_KLC1_Yacidic_2_6FUZ  ranked_1.pdb
# 1034  MLIG_NRP_CendR_1_2ORZ.DLIG_KLC1_Yacidic_2_6FUZ  ranked_2.pdb
# 1035  MLIG_NRP_CendR_1_2ORZ.DLIG_KLC1_Yacidic_2_6FUZ  ranked_3.pdb
# 1036  MLIG_NRP_CendR_1_2ORZ.DLIG_KLC1_Yacidic_2_6FUZ  ranked_4.pdb
# 1078          MLIG_PDZ_Class_1_1D5G.DLIG_PAM2_1_1JGN  ranked_1.pdb
# 1079          MLIG_PDZ_Class_1_1D5G.DLIG_PAM2_1_1JGN  ranked_2.pdb
# 1080          MLIG_PDZ_Class_1_1D5G.DLIG_PAM2_1_1JGN  ranked_3.pdb
# 1081          MLIG_PDZ_Class_1_1D5G.DLIG_PAM2_1_1JGN  ranked_4.pdb
# 1153   MLIG_SH3_CIN85_PxpxPR_1_2BZ8.DLIG_PAM2_1_1JGN  ranked_1.pdb
# 1155   MLIG_SH3_CIN85_PxpxPR_1_2BZ8.DLIG_PAM2_1_1JGN  ranked_3.pdb
# 1156   MLIG_SH3_CIN85_PxpxPR_1_2BZ8.DLIG_PAM2_1_1JGN  ranked_4.pdb
#
#       min_distance_x  min_distance_y
# 335        11.646098       12.319908
# 336        11.610141        0.000000
# 337        11.893074       14.745695
# 338        10.005889       10.803395
# 339        18.050923        0.000000
# 393        68.863720        0.000000
# 394        22.638168        0.000000
# 395        83.210614        0.000000
# 666        17.805032        0.000000
# 767         8.262786        8.353945
# 769         8.652122        8.834171
# 770        10.488932        0.000000
# 771        15.997593        0.000000
# 786        14.721818        0.000000
# 799        14.990403        0.000000
# 800        17.683367        0.000000
# 801        36.678640        0.000000
# 832         8.921937        9.236410
# 901         7.735588       11.388299
# 921        15.858028        0.000000
# 956        10.648053       13.261061
# 1033       15.566061        0.000000
# 1034       11.964645        0.000000
# 1035       18.263178        0.000000
# 1036       20.164709        0.000000
# 1078       11.270486        0.000000
# 1079        8.581291        8.999459
# 1080       14.668243        0.000000
# 1081       19.185307        0.000000
# 1153       12.476648        0.000000
# 1155       18.068955        0.000000
# 1156       12.134479        0.000000

# %%
column = "hydrophobic_interactions"
divergingRows = joinedData.query(f"({column}_x - {column}_y)**2 >= 0.001")
divergingRows[["structure_name", "file", f"{column}_x",f"{column}_y"]]
# Out:
# Empty DataFrame
# Columns: [structure_name, file, hydrophobic_interactions_x, hydrophobic_interactions_y]
# Index: []

# %% [markdown]
# ### Adding H to solved structures

# %% [markdown]
# Visualizing if H is currently present

# %%
import biotite.structure.io as biotiteIO
import biotite.structure as struc
import matplotlib.pyplot as plt

# %%
structures = {}
for path in solved_basePath.iterdir():
    if not path.is_file() and path.suffix.lower() == ".pdb":
        continue
    structure_name = path.stem
    structures[structure_name] = biotiteIO.pdb.get_structure(biotiteIO.pdb.PDBFile.read(path))

hydrogens_rel = {}
for name, structure in structures.items():
    if len(structure) != 1:
        raise ValueError("Multiple structures")
    s = structure[0]
    count = len(s)
    h_count = len(s[(s.element == "H")])
    hydrogens_rel[name] = h_count/count

dist = [r for name,r in hydrogens_rel.items()]
plt.hist(dist)
plt.title("Solved structures")
plt.ylabel("Count")
plt.xlabel("Relative amount of Hydrogen atoms in structure")
plt.show()

# %%
import pymol
exportPath = solved_basePath / ".." / "ISS DMI_solved_structures hydrogens"

# %%
for path in solved_basePath.iterdir():
    if not path.is_file() and path.suffix.lower() == ".pdb":
        continue
    print(path.stem)
    pymol.cmd.load(path, path.stem)
    pymol.cmd.h_add()
    pymol.cmd.save(exportPath / path.name)
    pymol.cmd.delete(path.stem)

# %% [markdown]
# Visualizing the exported data

# %%
structures = {}
for path in exportPath.iterdir():
    if not path.is_file() and path.suffix.lower() == ".pdb":
        continue
    structure_name = path.stem
    structures[structure_name] = biotiteIO.pdb.get_structure(biotiteIO.pdb.PDBFile.read(path))

hydrogens_rel = {}
for name, structure in structures.items():
    if len(structure) != 1:
        raise ValueError("Multiple structures")
    s = structure[0]
    count = len(s)
    h_count = len(s[(s.element == "H")])
    hydrogens_rel[name] = h_count/count

dist = [r for name,r in hydrogens_rel.items()]
plt.hist(dist)
plt.title("Solved structures with Hydrogens added")
plt.ylabel("Count")
plt.xlabel("Relative amount of Hydrogen atoms in structure")
plt.show()
