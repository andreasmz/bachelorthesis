# %% [markdown]
# # Benchmark set evaluation
# Created 2025-05-15
#
# It was found, that some structures are missing in either the known, random or mutations dataset. I think I know now why: Some DMI/DDI types have more than one PDB structure and vise versa a PDB structure could link to multiple DMI/DDI types. Now its time to investigate this one and for all

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.axes._axes import Axes
from matplotlib.figure import Figure
from pathlib import Path
from sklearn.metrics import roc_curve, roc_auc_score
import re
import tempfile
import shutil
import os
import subprocess
import sys
stdout, stderr = sys.stdout, sys.stderr
from typing import Literal

import pymol
from Bio.SeqUtils import seq1
from Bio.PDB import PDBParser
from Bio.PDB.Structure import Structure as BioPy_PDBStructure
from Bio.PDB.Model import Model as BioPy_PDBModel
from Bio.PDB.Chain import Chain
from Bio.PDB.PDBExceptions import PDBConstructionException
parser = PDBParser(QUIET=True)

class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

# %%
# Settings

# Path to resource folder with the structures and metadata tables
path_resources = Path(r"D:\Eigene Datein\dev\Uni\JGU Bio Bachelorthesis\Daten\resources")

path_AF2 = path_resources / "AF2"
path_AF3 = path_resources / "AF3_hydrogens"
path_solved = path_resources / "solved"

# %%
dataLee = pd.read_excel(path_resources / "benchmark set" / "Lee et al supplemental" / "44320_2023_5_moesm3_esm.xlsx", sheet_name="Minimal DMI dataset")
display(dataLee)
# Out:
#                  dmi_type                                 regular_expression  \
# 0       DEG_APCC_KENBOX_2                                              .KEN.
# 1              DEG_COP1_1  [STDE]{1,3}.{0,2}[TSDE].{2,3}VP[STDE]G{0,1}[FL...
# 2       DEG_Kelch_Keap1_1                                 [DNS].[DES][TNS]GE
# 3       DEG_Kelch_Keap1_2                                            QD.DLGV
# 4         DEG_MDM2_SWIB_1                            F[^P]{3}W[^P]{2,3}[VIL]
# ..                    ...                                                ...
# 131  LIG_ActinCP_TwfCPI_2                           F.[KR]P..[PAS].{0,3}[RK]
# 132    LIG_KLC1_Yacidic_2                      [ED].{0,1}[IYVLMTF]Y[LIV][DE]
# 133       LIG_LYPXL_SIV_4                                [PA]Y..[AV][^P]{3}L
# 134      TRG_DiLeu_BaEn_1                                     E..[^P]L[LIVM]
# 135    TRG_DiLeu_BaLyEn_6                                    [^E]..[RP]L[LI]
#
#     pdb_id                                            methods  \
# 0     4GGD  mutation analysis; pull down; x-ray crystallog...
# 1     5IGO  coimmunoprecipitation; competition binding; fl...
# 2     2FLU  alanine scanning; coimmunoprecipitation; compe...
# 3     3WN7  alanine scanning; glutathione s tranferase tag...
# 4     1YCR  fluorescence polarization spectroscopy; isothe...
# ..     ...                                                ...
# 131   7DS2  colocalization; comigration in non denaturing ...
# 132   6FUZ  alanine scanning; coimmunoprecipitation; fluor...
# 133   2XS1  biosensor; mutation analysis; western blot; x-...
# 134   4NEE  isothermal titration calorimetry; mutation ana...
# 135   2JKR  functional association; mutation analysis; phe...
#
#                                    organisms uniprot_motif uniprot_domain  \
# 0                               Homo sapiens        O60566         Q12834
# 1                               Homo sapiens        Q96RU8         P43254
# 2                               Homo sapiens        Q16236         Q14145
# 3                               Mus musculus        Q60795         Q9Z2X8
# 4                               Homo sapiens        P04637         Q00987
# ..                                       ...           ...            ...
# 131                             Mus musculus        Q91YR1         P14315
# 132                             Homo sapiens        Q9UQF2         O88447
# 133  Simian immunodeficiency virus - mac K6W        P05893         Q8WUM4
# 134                          HIV-1 M:B_HXB2R        P04601         P62744
# 135                             Homo sapiens        P01730         P62743
#
#     chain_motif chain_domain  chain_motif_start  chain_motif_end  \
# 0             D            B                  6               10
# 1             X            D                354              361
# 2             P            X                 77               82
# 3             B            A                 26               32
# 4             B            A                 19               26
# ..          ...          ...                ...              ...
# 131           C            B                323              333
# 132           A            A                707              711
# 133           B            A                 44               52
# 134           C            D                160              165
# 135           Q            I                  4                9
#
#      chain_domain_start  chain_domain_end motif_secondary_structure
# 0                   165               476                         L
# 1                   352               675                         L
# 2                   325               609                         L
# 3                   324               609                         H
# 4                    30               109                         H
# ..                  ...               ...                       ...
# 131                   2               244                         L
# 132                 214               436                         L
# 133                   2               698                         H
# 134                   1               142                         L
# 135                   1               142                         L
#
# [136 rows x 14 columns]

# %%
dataLee2 = pd.read_excel(path_resources / "benchmark set" / "Lee et al supplemental" / "44320_2023_5_moesm4_esm.xlsx", sheet_name="AF-MMv2.2 result")
display(dataLee2)
# Out:
#               prediction_name  chainA_length  chainB_length  model_id  \
# 0      DEG_APCC_KENBOX_2_4GGD            312              5  ranked_0
# 1      DEG_APCC_KENBOX_2_4GGD            312              5  ranked_1
# 2      DEG_APCC_KENBOX_2_4GGD            312              5  ranked_2
# 3      DEG_APCC_KENBOX_2_4GGD            312              5  ranked_3
# 4      DEG_APCC_KENBOX_2_4GGD            312              5  ranked_4
# ...                       ...            ...            ...       ...
# 2695  TRG_PTS1_2C0L_NAKL.NAKD            305              4  ranked_0
# 2696  TRG_PTS1_2C0L_NAKL.NAKD            305              4  ranked_1
# 2697  TRG_PTS1_2C0L_NAKL.NAKD            305              4  ranked_2
# 2698  TRG_PTS1_2C0L_NAKL.NAKD            305              4  ranked_3
# 2699  TRG_PTS1_2C0L_NAKL.NAKD            305              4  ranked_4
#
#       model_confidence  chainA_intf_avg_plddt  chainB_intf_avg_plddt  \
# 0             0.887117              96.107999              77.495999
# 1             0.871984              95.793846              73.986000
# 2             0.760784              95.547501              57.906001
# 3             0.413662              94.646667              21.510000
# 4             0.359078              94.830001              19.753333
# ...                ...                    ...                    ...
# 2695          0.877999              96.388571              74.585001
# 2696          0.868754              96.614545              75.270000
# 2697          0.852158              96.452917              75.197498
# 2698          0.819368              95.764286              69.147499
# 2699          0.790574              95.154999              64.405001
#
#       intf_avg_plddt    pDockQ       iPAE  num_chainA_intf_res  \
# 0          91.454999  0.162263   3.311542                   15
# 1          89.736111  0.145001   3.395909                   13
# 2          86.585239  0.116743   6.166772                   16
# 3          76.362500  0.036380  16.713730                    9
# 4          72.307001  0.029969  18.696838                    7
# ...              ...       ...        ...                  ...
# 2695       92.900000  0.234389   2.903771                   21
# 2696       93.330769  0.233830   3.026700                   22
# 2697       93.416428  0.223745   3.121255                   24
# 2698       91.505600  0.204897   4.233161                   21
# 2699       90.029999  0.181055   4.798036                   20
#
#       num_chainB_intf_res  num_res_res_contact  num_atom_atom_contact  \
# 0                       5                   23                    208
# 1                       5                   20                    190
# 2                       5                   27                    237
# 3                       3                   11                     83
# 4                       3                    9                    108
# ...                   ...                  ...                    ...
# 2695                    4                   31                    271
# 2696                    4                   31                    262
# 2697                    4                   35                    272
# 2698                    4                   31                    258
# 2699                    4                   30                    235
#
#      num_mutation_in_motif  label
# 0            known minimal      1
# 1            known minimal      1
# 2            known minimal      1
# 3            known minimal      1
# 4            known minimal      1
# ...                    ...    ...
# 2695                     1      0
# 2696                     1      0
# 2697                     1      0
# 2698                     1      0
# 2699                     1      0
#
# [2700 rows x 16 columns]

# %%
dataAF2 = pd.read_csv(path_AF2 / "AF2_metrics.tsv", sep="\t")
for c in ["chainA_start", "chainA_end", "chainB_start", "chainB_end", "num_mutations", "num_align_atoms_domain", "num_align_resi_domain", "hbonds", "salt_bridges", "hydrophobic_interactions"]:
    if c not in dataAF2.columns:
        print(f"Column {bcolors.FAIL}{c}{bcolors.ENDC} not (yet) in data frame")
        continue
    dataAF2[c] = dataAF2[c].astype(pd.Int64Dtype())
display(dataAF2)
# Out:
#                  project_name run_id benchmark_set  \
# 0         AlphaFold_benchmark  run37     known_DMI
# 1         AlphaFold_benchmark  run37     known_DMI
# 2         AlphaFold_benchmark  run37     known_DMI
# 3         AlphaFold_benchmark  run37     known_DMI
# 4         AlphaFold_benchmark  run37     known_DMI
# ...                       ...    ...           ...
# 3175  AlphaFold_benchmark_DDI   run6    random_DDI
# 3176  AlphaFold_benchmark_DDI   run6    random_DDI
# 3177  AlphaFold_benchmark_DDI   run6    random_DDI
# 3178  AlphaFold_benchmark_DDI   run6    random_DDI
# 3179  AlphaFold_benchmark_DDI   run6    random_DDI
#
#                                     prediction_name  model_id  chainA_length  \
# 0                            DEG_APCC_KENBOX_2_4GGD  ranked_0            312
# 1                            DEG_APCC_KENBOX_2_4GGD  ranked_1            312
# 2                            DEG_APCC_KENBOX_2_4GGD  ranked_2            312
# 3                            DEG_APCC_KENBOX_2_4GGD  ranked_3            312
# 4                            DEG_APCC_KENBOX_2_4GGD  ranked_4            312
# ...                                             ...       ...            ...
# 3175  D1PF18773_PF00071_2X19.D2PF00009_PF01873_2D74  ranked_0             60
# 3176  D1PF18773_PF00071_2X19.D2PF00009_PF01873_2D74  ranked_1             60
# 3177  D1PF18773_PF00071_2X19.D2PF00009_PF01873_2D74  ranked_2             60
# 3178  D1PF18773_PF00071_2X19.D2PF00009_PF01873_2D74  ranked_3             60
# 3179  D1PF18773_PF00071_2X19.D2PF00009_PF01873_2D74  ranked_4             60
#
#       chainB_length chainA_id chainB_id  chainA_start  ...     DockQ  \
# 0                 5         A         B           165  ...  0.878344
# 1                 5         A         B           165  ...  0.880716
# 2                 5         A         B           165  ...  0.883186
# 3                 5         A         B           165  ...  0.475511
# 4                 5         A         B           165  ...  0.223400
# ...             ...       ...       ...           ...  ...       ...
# 3175            113         B         B           392  ...       NaN
# 3176            113         B         B           392  ...       NaN
# 3177            113         B         B           392  ...       NaN
# 3178            113         B         B           392  ...       NaN
# 3179            113         B         B           392  ...       NaN
#
#          iRMSD     LRMSD   Fnonnat buried_area min_distance disulfide_bonds  \
# 0     0.603831  1.575394  0.086957     613.651        6.063             0.0
# 1     0.418230  1.100588  0.050000     580.310        6.083             0.0
# 2     0.641834  1.776257  0.185185     662.104        6.072             0.0
# 3     1.686332  5.358800  0.363636     398.498        5.417             0.0
# 4     2.928606  9.908745  0.888889     323.304        5.092             0.0
# ...        ...       ...       ...         ...          ...             ...
# 3175       NaN       NaN       NaN    1617.382        5.591             0.0
# 3176       NaN       NaN       NaN     791.256        6.373             0.0
# 3177       NaN       NaN       NaN     882.547        7.906             0.0
# 3178       NaN       NaN       NaN    1020.896        4.628             0.0
# 3179       NaN       NaN       NaN     882.571        5.461             0.0
#
#      salt_bridges hbonds hydrophobic_interactions
# 0               0      9                        0
# 1               0      9                        0
# 2               0     10                        3
# 3               0      2                        0
# 4               0      2                        9
# ...           ...    ...                      ...
# 3175            3      7                       56
# 3176            0      3                        7
# 3177            1      2                       11
# 3178            3      7                       44
# 3179            3     10                       14
#
# [3180 rows x 49 columns]

# %% [markdown]
# ### 1 Finding differences in the datasets

# %%
dataMerged = pd.merge(
    left=dataLee,
    right=dataAF2[(dataAF2["benchmark_set"] == "known_DMI") & (dataAF2["model_id"] == "ranked_0")],
    left_on=["dmi_type"],
    right_on=["ELM_instance"],
    how="outer"
)
display(dataMerged)
# Out:
#                  dmi_type                                 regular_expression  \
# 0       DEG_APCC_KENBOX_2                                              .KEN.
# 1              DEG_COP1_1  [STDE]{1,3}.{0,2}[TSDE].{2,3}VP[STDE]G{0,1}[FL...
# 2       DEG_Kelch_Keap1_1                                 [DNS].[DES][TNS]GE
# 3       DEG_Kelch_Keap1_2                                            QD.DLGV
# 4         DEG_MDM2_SWIB_1                            F[^P]{3}W[^P]{2,3}[VIL]
# ..                    ...                                                ...
# 131         TRG_ER_FFAT_1    [EDS].{0,4}[ED][FY][FYKREM][DE][AC].{1,2}[EDST]
# 132  TRG_LysEnd_GGAAcLL_1                                       D..LL.{1,2}$
# 133        TRG_NES_CRM1_1  ([DEQ].{0,1}[LIM].{2,3}[LIVMF][^P]{2,3}[LMVF]....
# 134   TRG_NLS_Bipartite_1  [KR][KR].{7,15}[^DE]((K[RK])|(RK))(([^DE][KR])...
# 135              TRG_PTS1  (.[SAPTC][KRH][LMFI]$)|([KRH][SAPTC][NTS][LMFI]$)
#
#     pdb_id                                            methods     organisms  \
# 0     4GGD  mutation analysis; pull down; x-ray crystallog...  Homo sapiens
# 1     5IGO  coimmunoprecipitation; competition binding; fl...  Homo sapiens
# 2     2FLU  alanine scanning; coimmunoprecipitation; compe...  Homo sapiens
# 3     3WN7  alanine scanning; glutathione s tranferase tag...  Mus musculus
# 4     1YCR  fluorescence polarization spectroscopy; isothe...  Homo sapiens
# ..     ...                                                ...           ...
# 131   2RR3  classical fluorescence spectroscopy; confocal ...  Homo sapiens
# 132   1JWG  isothermal titration calorimetry; mutation ana...  Homo sapiens
# 133   3GB8  mutation analysis; pull down; x-ray crystallog...  Homo sapiens
# 134   1PJM  colocalization; mutation analysis; x-ray cryst...  Homo sapiens
# 135   2C0L                              x-ray crystallography  Homo sapiens
#
#     uniprot_motif uniprot_domain chain_motif chain_domain  chain_motif_start  \
# 0          O60566         Q12834           D            B                  6
# 1          Q96RU8         P43254           X            D                354
# 2          Q16236         Q14145           P            X                 77
# 3          Q60795         Q9Z2X8           B            A                 26
# 4          P04637         Q00987           B            A                 19
# ..            ...            ...         ...          ...                ...
# 131        P22059         Q9P0L0           B            A                356
# 132        P11717         Q9UJY5           C            A                  7
# 133        O95149         O14980           B            A                  2
# 134        P06400         P52293           A            B                860
# 135        P22307         P50542           B            A                140
#
#      ...     DockQ     iRMSD      LRMSD   Fnonnat buried_area min_distance  \
# 0    ...  0.878344  0.603831   1.575394  0.086957     613.651        6.063
# 1    ...  0.203083  3.647857  11.785731  0.818182    1025.173        5.075
# 2    ...  0.956840  0.406243   0.409987  0.135135     853.680        5.658
# 3    ...  0.627900  1.098010   3.811533  0.357143     847.029        5.699
# 4    ...  0.927639  0.491499   0.974915  0.038462     969.729        4.725
# ..   ...       ...       ...        ...       ...         ...          ...
# 131  ...  0.832137  1.023273   1.642793  0.128205    1121.818        4.348
# 132  ...  0.949574  0.470555   1.451951  0.093750    1066.671        5.933
# 133  ...  0.683162  1.423170   2.824227  0.153846    1389.344        4.832
# 134  ...  0.838144  0.780334   2.332849  0.160000    2256.518        4.881
# 135  ...  0.968527  0.356636   0.916972  0.029412     883.012        4.542
#
#     disulfide_bonds salt_bridges hbonds  hydrophobic_interactions
# 0               0.0            0      9                         0
# 1               0.0            0      6                        54
# 2               0.0            4     12                         6
# 3               0.0            2      4                        18
# 4               0.0            0      2                       104
# ..              ...          ...    ...                       ...
# 131             0.0            0      7                        53
# 132             0.0            1      6                        60
# 133             0.0            3      5                       104
# 134             0.0            4     20                        50
# 135             0.0            3     12                        29
#
# [136 rows x 63 columns]

# %%
dataAF2[dataAF2["hbonds"].isna()]
# Out:
#                  project_name run_id benchmark_set  \
# 2860  AlphaFold_benchmark_DDI   run5     known_DDI
# 2861  AlphaFold_benchmark_DDI   run5     known_DDI
# 2862  AlphaFold_benchmark_DDI   run5     known_DDI
# 2863  AlphaFold_benchmark_DDI   run5     known_DDI
# 2864  AlphaFold_benchmark_DDI   run5     known_DDI
# 2920  AlphaFold_benchmark_DDI   run5     known_DDI
# 2921  AlphaFold_benchmark_DDI   run5     known_DDI
# 2922  AlphaFold_benchmark_DDI   run5     known_DDI
# 2923  AlphaFold_benchmark_DDI   run5     known_DDI
# 2924  AlphaFold_benchmark_DDI   run5     known_DDI
#
#                                         prediction_name  model_id  \
# 2860  PF07724_PF00227_1OFH_C_resi39_resi340.H_resi1_...  ranked_0
# 2861  PF07724_PF00227_1OFH_C_resi39_resi340.H_resi1_...  ranked_1
# 2862  PF07724_PF00227_1OFH_C_resi39_resi340.H_resi1_...  ranked_2
# 2863  PF07724_PF00227_1OFH_C_resi39_resi340.H_resi1_...  ranked_3
# 2864  PF07724_PF00227_1OFH_C_resi39_resi340.H_resi1_...  ranked_4
# 2920  PF14978_PF00327_3J7Y_o_resi13_resi101.Z_resi57...  ranked_0
# 2921  PF14978_PF00327_3J7Y_o_resi13_resi101.Z_resi57...  ranked_1
# 2922  PF14978_PF00327_3J7Y_o_resi13_resi101.Z_resi57...  ranked_2
# 2923  PF14978_PF00327_3J7Y_o_resi13_resi101.Z_resi57...  ranked_3
# 2924  PF14978_PF00327_3J7Y_o_resi13_resi101.Z_resi57...  ranked_4
#
#       chainA_length  chainB_length chainA_id chainB_id  chainA_start  ...  \
# 2860            168            172         C         H            39  ...
# 2861            168            172         C         H            39  ...
# 2862            168            172         C         H            39  ...
# 2863            168            172         C         H            39  ...
# 2864            168            172         C         H            39  ...
# 2920             89             71         o         Z            13  ...
# 2921             89             71         o         Z            13  ...
# 2922             89             71         o         Z            13  ...
# 2923             89             71         o         Z            13  ...
# 2924             89             71         o         Z            13  ...
#
#       DockQ  iRMSD  LRMSD Fnonnat buried_area min_distance disulfide_bonds  \
# 2860    NaN    NaN    NaN     NaN         NaN          NaN             NaN
# 2861    NaN    NaN    NaN     NaN         NaN          NaN             NaN
# 2862    NaN    NaN    NaN     NaN         NaN          NaN             NaN
# 2863    NaN    NaN    NaN     NaN         NaN          NaN             NaN
# 2864    NaN    NaN    NaN     NaN         NaN          NaN             NaN
# 2920    NaN    NaN    NaN     NaN         NaN          NaN             NaN
# 2921    NaN    NaN    NaN     NaN         NaN          NaN             NaN
# 2922    NaN    NaN    NaN     NaN         NaN          NaN             NaN
# 2923    NaN    NaN    NaN     NaN         NaN          NaN             NaN
# 2924    NaN    NaN    NaN     NaN         NaN          NaN             NaN
#
#      salt_bridges hbonds hydrophobic_interactions
# 2860         <NA>   <NA>                     <NA>
# 2861         <NA>   <NA>                     <NA>
# 2862         <NA>   <NA>                     <NA>
# 2863         <NA>   <NA>                     <NA>
# 2864         <NA>   <NA>                     <NA>
# 2920         <NA>   <NA>                     <NA>
# 2921         <NA>   <NA>                     <NA>
# 2922         <NA>   <NA>                     <NA>
# 2923         <NA>   <NA>                     <NA>
# 2924         <NA>   <NA>                     <NA>
#
# [10 rows x 49 columns]

# %%
dataMerged[dataMerged["pdb_id"].isna()]
# Out:
# Empty DataFrame
# Columns: [dmi_type, regular_expression, pdb_id, methods, organisms, uniprot_motif, uniprot_domain, chain_motif, chain_domain, chain_motif_start, chain_motif_end, chain_domain_start, chain_domain_end, motif_secondary_structure, project_name, run_id, benchmark_set, prediction_name, model_id, chainA_length, chainB_length, chainA_id, chainB_id, chainA_start, chainA_end, chainB_start, chainB_end, PDB_id, ELM_instance, DDI_pfam_id, PDB_id_random_paired, ELM_instance_random_paired, DDI_pfam_id_random_paired, sequence_initial, sequence_mutated, num_mutations, model_confidence, chainA_intf_avg_plddt, chainB_intf_avg_plddt, intf_avg_plddt, pDockQ, iPAE, num_chainA_intf_res, num_chainB_intf_res, num_res_res_contact, num_atom_atom_contact, align_score_domain, num_align_atoms_domain, num_align_resi_domain, RMSD_domain, RMSD_backbone_peptide, RMSD_all_atom_peptide, RMSD_all_atom, DockQ, iRMSD, LRMSD, Fnonnat, buried_area, min_distance, disulfide_bonds, salt_bridges, hbonds, hydrophobic_interactions]
# Index: []
#
# [0 rows x 63 columns]

# %% [markdown]
# ---> Thats good, the known DMI are equal. But where are the differences in the other comming from?

# %%
dataMerged[dataMerged["chain_domain_start"] != dataMerged["chainA_start"]]
# Out:
#            dmi_type                                 regular_expression pdb_id  \
# 80       LIG_MYND_2                                              PP.LI   2ODD
# 102  LIG_RPA_C_Vert  [KRS]I[^P][^P][NK][KR][^P][^P]A[^P][^P][RKL][R...   1DPU
# 103  LIG_Rb_LxCxE_1  [DEST].{0,4}[LI].C.E.{1,4}[FLMIVAWPHY].{0,8}[D...   1GH6
#
#                                                methods        organisms  \
# 80   fluorescence polarization spectroscopy; isothe...     Homo sapiens
# 102  isothermal titration calorimetry; mutation ana...     Homo sapiens
# 103  coimmunoprecipitation; glutathione s tranferas...  Simian virus 40
#
#     uniprot_motif uniprot_domain chain_motif chain_domain  chain_motif_start  \
# 80         Q9Y618         Q06455           B            A               1105
# 102        P13051         P15927           B            A                 73
# 103        P03070         P06400           A            B                101
#
#      ...     DockQ     iRMSD      LRMSD   Fnonnat buried_area min_distance  \
# 80   ...  0.784829  1.963057   1.018266  0.071429     796.717        4.986
# 102  ...  0.667361  1.984128   4.182533  0.333333     936.565        3.966
# 103  ...  0.066520  7.156339  19.661015  1.000000    1446.210        6.370
#
#     disulfide_bonds salt_bridges hbonds  hydrophobic_interactions
# 80              0.0            0      6                        51
# 102             0.0            1      6                        14
# 103             0.0            1      6                        67
#
# [3 rows x 63 columns]

# %%
dataMerged2 = pd.merge(
    left=dataLee2,
    right=dataAF2,
    on=["prediction_name", "model_id"],
    suffixes=["_Lee", "_AF2"],
    how="outer"
)
display(dataMerged2)
# Out:
#                                     prediction_name  chainA_length_Lee  \
# 0     D1PF00009_PF01873_2D74.D2PF00026_PF06394_1F34                NaN
# 1     D1PF00009_PF01873_2D74.D2PF00026_PF06394_1F34                NaN
# 2     D1PF00009_PF01873_2D74.D2PF00026_PF06394_1F34                NaN
# 3     D1PF00009_PF01873_2D74.D2PF00026_PF06394_1F34                NaN
# 4     D1PF00009_PF01873_2D74.D2PF00026_PF06394_1F34                NaN
# ...                                             ...                ...
# 3175                        TRG_PTS1_2C0L_NAKL.NAKD              305.0
# 3176                        TRG_PTS1_2C0L_NAKL.NAKD              305.0
# 3177                        TRG_PTS1_2C0L_NAKL.NAKD              305.0
# 3178                        TRG_PTS1_2C0L_NAKL.NAKD              305.0
# 3179                        TRG_PTS1_2C0L_NAKL.NAKD              305.0
#
#       chainB_length_Lee  model_id  model_confidence_Lee  \
# 0                   NaN  ranked_0                   NaN
# 1                   NaN  ranked_1                   NaN
# 2                   NaN  ranked_2                   NaN
# 3                   NaN  ranked_3                   NaN
# 4                   NaN  ranked_4                   NaN
# ...                 ...       ...                   ...
# 3175                4.0  ranked_0              0.877999
# 3176                4.0  ranked_1              0.868754
# 3177                4.0  ranked_2              0.852158
# 3178                4.0  ranked_3              0.819368
# 3179                4.0  ranked_4              0.790574
#
#       chainA_intf_avg_plddt_Lee  chainB_intf_avg_plddt_Lee  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3175                  96.388571                  74.585001
# 3176                  96.614545                  75.270000
# 3177                  96.452917                  75.197498
# 3178                  95.764286                  69.147499
# 3179                  95.154999                  64.405001
#
#       intf_avg_plddt_Lee  pDockQ_Lee  iPAE_Lee  ...  DockQ  iRMSD  LRMSD  \
# 0                    NaN         NaN       NaN  ...    NaN    NaN    NaN
# 1                    NaN         NaN       NaN  ...    NaN    NaN    NaN
# 2                    NaN         NaN       NaN  ...    NaN    NaN    NaN
# 3                    NaN         NaN       NaN  ...    NaN    NaN    NaN
# 4                    NaN         NaN       NaN  ...    NaN    NaN    NaN
# ...                  ...         ...       ...  ...    ...    ...    ...
# 3175           92.900000    0.234389  2.903771  ...    NaN    NaN    NaN
# 3176           93.330769    0.233830  3.026700  ...    NaN    NaN    NaN
# 3177           93.416428    0.223745  3.121255  ...    NaN    NaN    NaN
# 3178           91.505600    0.204897  4.233161  ...    NaN    NaN    NaN
# 3179           90.029999    0.181055  4.798036  ...    NaN    NaN    NaN
#
#       Fnonnat buried_area  min_distance disulfide_bonds salt_bridges hbonds  \
# 0         NaN    1692.652         4.191             0.0            0      1
# 1         NaN    1708.317         3.670             0.0            0      3
# 2         NaN    1907.898         4.643             0.0            1      1
# 3         NaN    1577.972         3.718             0.0            0      5
# 4         NaN    2139.539         3.955             0.0            1     15
# ...       ...         ...           ...             ...          ...    ...
# 3175      NaN     839.162         4.782             0.0            3     10
# 3176      NaN     862.629         4.900             0.0            3      8
# 3177      NaN     861.115         4.704             0.0            2     12
# 3178      NaN     854.038         4.943             0.0            2     11
# 3179      NaN     851.724         5.097             0.0            3     10
#
#       hydrophobic_interactions
# 0                           86
# 1                           96
# 2                           79
# 3                          107
# 4                          101
# ...                        ...
# 3175                        11
# 3176                        10
# 3177                         9
# 3178                         9
# 3179                         8
#
# [3180 rows x 63 columns]

# %%
dataMerged2[dataMerged2["chainA_length_Lee"].isna() & ~(dataMerged2["benchmark_set"].isin(["known_DDI", "random_DDI"]))]
# Out:
# Empty DataFrame
# Columns: [prediction_name, chainA_length_Lee, chainB_length_Lee, model_id, model_confidence_Lee, chainA_intf_avg_plddt_Lee, chainB_intf_avg_plddt_Lee, intf_avg_plddt_Lee, pDockQ_Lee, iPAE_Lee, num_chainA_intf_res_Lee, num_chainB_intf_res_Lee, num_res_res_contact_Lee, num_atom_atom_contact_Lee, num_mutation_in_motif, label, project_name, run_id, benchmark_set, chainA_length_AF2, chainB_length_AF2, chainA_id, chainB_id, chainA_start, chainA_end, chainB_start, chainB_end, PDB_id, ELM_instance, DDI_pfam_id, PDB_id_random_paired, ELM_instance_random_paired, DDI_pfam_id_random_paired, sequence_initial, sequence_mutated, num_mutations, model_confidence_AF2, chainA_intf_avg_plddt_AF2, chainB_intf_avg_plddt_AF2, intf_avg_plddt_AF2, pDockQ_AF2, iPAE_AF2, num_chainA_intf_res_AF2, num_chainB_intf_res_AF2, num_res_res_contact_AF2, num_atom_atom_contact_AF2, align_score_domain, num_align_atoms_domain, num_align_resi_domain, RMSD_domain, RMSD_backbone_peptide, RMSD_all_atom_peptide, RMSD_all_atom, DockQ, iRMSD, LRMSD, Fnonnat, buried_area, min_distance, disulfide_bonds, salt_bridges, hbonds, hydrophobic_interactions]
# Index: []
#
# [0 rows x 63 columns]

# %%
dataMerged2[dataMerged2["chainA_length_Lee"].isna() & ~(dataMerged2["benchmark_set"].isin(["known_DDI", "random_DDI"]))]

# %%
dataMerged2.columns
# Out:
# Index(['prediction_name', 'chainA_length_Lee', 'chainB_length_Lee', 'model_id',
#        'model_confidence_Lee', 'chainA_intf_avg_plddt_Lee',
#        'chainB_intf_avg_plddt_Lee', 'intf_avg_plddt_Lee', 'pDockQ_Lee',
#        'iPAE_Lee', 'num_chainA_intf_res_Lee', 'num_chainB_intf_res_Lee',
#        'num_res_res_contact_Lee', 'num_atom_atom_contact_Lee',
#        'num_mutation_in_motif', 'label', 'project_name', 'run_id',
#        'benchmark_set', 'chainA_length_AF2', 'chainB_length_AF2', 'chainA_id',
#        'chainB_id', 'chainA_start', 'chainA_end', 'chainB_start', 'chainB_end',
#        'PDB_id', 'ELM_instance', 'DDI_pfam_id', 'PDB_id_random_paired',
#        'ELM_instance_random_paired', 'DDI_pfam_id_random_paired',
#        'sequence_initial', 'sequence_mutated', 'num_mutations',
#        'model_confidence_AF2', 'chainA_intf_avg_plddt_AF2',
#        'chainB_intf_avg_plddt_AF2', 'intf_avg_plddt_AF2', 'pDockQ_AF2',
#        'iPAE_AF2', 'num_chainA_intf_res_AF2', 'num_chainB_intf_res_AF2',
#        'num_res_res_contact_AF2', 'num_atom_atom_contact_AF2',
#        'align_score_domain', 'num_align_atoms_domain', 'num_align_resi_domain',
#        'RMSD_domain', 'RMSD_backbone_peptide', 'RMSD_all_atom_peptide',
#        'RMSD_all_atom', 'DockQ', 'iRMSD', 'LRMSD', 'Fnonnat', 'buried_area',
#        'min_distance', 'disulfide_bonds', 'salt_bridges', 'hbonds',
#        'hydrophobic_interactions'],
#       dtype='object')

# %%
dataMerged2[((dataMerged2["num_atom_atom_contact_AF2"] - dataMerged2["num_atom_atom_contact_Lee"])**2 > 0.000001) & (dataMerged2["benchmark_set"].str.contains("DMI"))]
# Out:
# Empty DataFrame
# Columns: [prediction_name, chainA_length_Lee, chainB_length_Lee, model_id, model_confidence_Lee, chainA_intf_avg_plddt_Lee, chainB_intf_avg_plddt_Lee, intf_avg_plddt_Lee, pDockQ_Lee, iPAE_Lee, num_chainA_intf_res_Lee, num_chainB_intf_res_Lee, num_res_res_contact_Lee, num_atom_atom_contact_Lee, num_mutation_in_motif, label, project_name, run_id, benchmark_set, chainA_length_AF2, chainB_length_AF2, chainA_id, chainB_id, chainA_start, chainA_end, chainB_start, chainB_end, PDB_id, ELM_instance, DDI_pfam_id, PDB_id_random_paired, ELM_instance_random_paired, DDI_pfam_id_random_paired, sequence_initial, sequence_mutated, num_mutations, model_confidence_AF2, chainA_intf_avg_plddt_AF2, chainB_intf_avg_plddt_AF2, intf_avg_plddt_AF2, pDockQ_AF2, iPAE_AF2, num_chainA_intf_res_AF2, num_chainB_intf_res_AF2, num_res_res_contact_AF2, num_atom_atom_contact_AF2, align_score_domain, num_align_atoms_domain, num_align_resi_domain, RMSD_domain, RMSD_backbone_peptide, RMSD_all_atom_peptide, RMSD_all_atom, DockQ, iRMSD, LRMSD, Fnonnat, buried_area, min_distance, disulfide_bonds, salt_bridges, hbonds, hydrophobic_interactions]
# Index: []
#
# [0 rows x 63 columns]
