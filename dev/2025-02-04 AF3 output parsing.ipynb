# %% [markdown]
# # Parsing the output of the new AF3 models
# 2025-02-04 by Andreas
#
# Script for parsing the AF3 output into a single file

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import re

# %%
outputBase1 = Path(r"L:\imb-luckgr2\projects\AlphaFold\AlphaFold3\AlphaFold_benchmark_DMI")
outputBase2 = Path(r"L:\imb-luckgr2\projects\AlphaFold\AlphaFold3\AlphaFold_benchmark_DDI")
outputFolders = [p for p in outputBase1.iterdir() if p.is_dir()] + [p for p in outputBase2.iterdir() if p.is_dir()]
for p in outputFolders:
    print(p)
# Out:
# L:\imb-luckgr2\projects\AlphaFold\AlphaFold3\AlphaFold_benchmark_DMI\known_extension
# L:\imb-luckgr2\projects\AlphaFold\AlphaFold3\AlphaFold_benchmark_DMI\known_minimal
# L:\imb-luckgr2\projects\AlphaFold\AlphaFold3\AlphaFold_benchmark_DMI\mutations
# L:\imb-luckgr2\projects\AlphaFold\AlphaFold3\AlphaFold_benchmark_DMI\random_minimal
# L:\imb-luckgr2\projects\AlphaFold\AlphaFold3\AlphaFold_benchmark_DDI\known_ddi
# L:\imb-luckgr2\projects\AlphaFold\AlphaFold3\AlphaFold_benchmark_DDI\random_ddi

# %%
dataAF = pd.DataFrame()
missformedOutputs = pd.DataFrame(columns=["benchmark_set", "prediction_name", "model_seed", "reason"])
missingOutputs = pd.DataFrame(columns=["benchmark_set",  "prediction_name"])
emptyOutputs = pd.DataFrame(columns=["benchmark_set", "nextflow_name"])

for outputFolder in outputFolders:
    print(f"Checking folder {outputFolder.name}")
    benchmark_set = outputFolder.name
    nextflowFolders = [p for p in outputFolder.iterdir() if p.is_dir()]
    for nextflowFolder in nextflowFolders:
        print(f"\t{nextflowFolder.name}")
        if not (metricPath := (nextflowFolder / "alphafold3_metrics.tsv")).exists():
            emptyOutputs.loc[len(emptyOutputs)] = {"benchmark_set":benchmark_set, "nextflow_name": nextflowFolder.name}
            continue
        metricFile = pd.read_csv(metricPath, delimiter="\t", header=0)
        metricFile["benchmark_set"] = benchmark_set
        metricFile["prediction_file"] = None
        if not metricFile.shape[0] >= 1:
            emptyOutputs.loc[len(emptyOutputs)] = {"benchmark_set":benchmark_set, "nextflow_name": nextflowFolder.name}
            continue

        prediction_name = metricFile["prediction_name"][0]
        if not len(set(metricFile["prediction_name"])) == 1:
            missformedOutputs.loc[len(missformedOutputs)] = {"benchmark_set": benchmark_set, "prediction_name": prediction_name, "reason": "multiple prediction_name for one structure"}
            continue
        
        if not (structureFolder := nextflowFolder / "predictions" / "alphafold3" / prediction_name).exists():
            missformedOutputs.loc[len(missformedOutputs)] = {"benchmark_set": benchmark_set, "prediction_name": prediction_name, "reason": "prediction folder does not exist"}
            continue
        for model_file in [(p / "model.cif") for p in structureFolder.iterdir() if p.is_dir() and (p / "model.cif").exists()]:
            model_seed = model_file.parent.name
            if len(metricFile.loc[metricFile["model_id"] == model_seed, ["prediction_file"]]) == 0:
                missformedOutputs.loc[len(missformedOutputs)] = {"benchmark_set": benchmark_set, "prediction_name": prediction_name, "reason": "model seed is not contained in tsv file"}
                continue
            metricFile.loc[metricFile["model_id"] == model_seed, ["prediction_file"]] = model_file
        
        metricFile.sort_values(by=['ranking_score'], ascending=False, ignore_index=True, inplace=True)
        metricFile["model_id"] = metricFile.apply(lambda r: f"ranked_{int(r.name)}", axis=1)
        dataAF = pd.concat([dataAF, metricFile], ignore_index=True)

    print(f"Checking inputs in folder {outputFolder.name}")
    nextflow_inputs = [f for f in outputFolder.iterdir() if f.is_file() and f.suffix.lower() == ".json"]
    for nextflow_input in nextflow_inputs:
        prediction_name = nextflow_input.stem
        if (dataAF[np.logical_and(dataAF["benchmark_set"] == benchmark_set, dataAF["prediction_name"] == prediction_name.lower())]).shape[0] == 0:
            missingOutputs.loc[len(missingOutputs)] = {"benchmark_set": benchmark_set, "prediction_name": prediction_name}
        else:
            dataAF[np.logical_and(dataAF["benchmark_set"] == benchmark_set, dataAF["prediction_name"] == prediction_name.lower())]["prediction_name"] == prediction_name # Correcting lowercase by AF3

# Finding duplicates
duplicateOutputs = dataAF[dataAF.duplicated(subset=["prediction_name", "model_id"], keep=False)]
# Out:
# Checking folder known_extension
# 	sad_austin
# 	sharp_woese
# 	sad_picasso
# 	fervent_bassi
# 	thirsty_visvesvaraya
# 	exotic_wiles
# 	peaceful_elion
# 	loquacious_dijkstra
# 	high_sinoussi
# 	fabulous_waddington
# 	desperate_church
# 	boring_venter
# 	jolly_dalembert
# 	cheeky_kowalevski
# 	magical_ride
# 	compassionate_joliot
# 	deadly_caravaggio
# 	determined_jepsen
# 	extravagant_pesquet
# 	sad_raman
# 	high_goldberg
# 	jovial_bhabha
# 	nice_brazil
# 	loquacious_minsky
# 	thirsty_poitras
# 	tiny_knuth
# 	shrivelled_gates
# 	maniac_wescoff
# 	nice_heisenberg
# 	special_koch
# 	clever_moriondo
# 	zen_perlman
# 	scruffy_miescher
# 	exotic_brazil
# 	mad_kirch
# 	loquacious_cantor
# 	gloomy_goodall
# 	stupefied_hawking
# 	cranky_noether
# 	tiny_poincare
# 	fabulous_kalam
# 	spontaneous_brattain
# 	trusting_caravaggio
# 	adoring_albattani
# 	prickly_gautier
# 	exotic_ekeblad
# 	clever_ardinghelli
# 	nostalgic_bell
# 	friendly_almeida
# 	happy_linnaeus
# 	special_monod
# 	loving_hodgkin
# 	hungry_sanger
# 	jovial_lattes
# 	magical_boltzmann
# 	elegant_mcnulty
# 	curious_engelbart
# 	distracted_avogadro
# 	lethal_tuckerman
# 	boring_edison
# 	nice_volta
# 	infallible_edison
# 	sad_ride
# 	nauseous_yalow
# 	suspicious_snyder
# 	confident_shockley
# 	wise_church
# 	maniac_bell
# 	evil_lumiere
# 	loquacious_morse
# 	ridiculous_bernard
# 	jovial_sanger
# 	berserk_boyd
# 	elated_wright
# 	thirsty_edison
# 	curious_kalam
# 	distracted_hugle
# 	determined_mendel
# 	angry_maxwell
# 	intergalactic_payne
# 	hopeful_goodall
# 	goofy_goldwasser
# 	magical_northcutt
# 	stupefied_jennings
# 	special_swanson
# 	voluminous_almeida
# 	furious_shockley
# 	spontaneous_euclid
# 	friendly_hodgkin
# 	gloomy_lalande
# 	pensive_faraday
# 	fervent_roentgen
# 	adoring_edison
# 	lethal_gates
# 	mighty_planck
# 	gigantic_lalande
# 	drunk_fermat
# 	friendly_feynman
# 	lonely_swartz
# 	nice_aryabhata
# 	fervent_crick
# 	disturbed_booth
# 	romantic_bose
# 	sad_torvalds
# 	special_shirley
# 	curious_poitras
# 	condescending_wilson
# 	loquacious_tuckerman
# 	pedantic_brahmagupta
# 	backstabbing_fermat
# 	loving_gilbert
# 	clever_visvesvaraya
# 	insane_volta
# 	deadly_cray
# 	thirsty_engelbart
# 	extravagant_faggin
# 	modest_pike
# 	wise_visvesvaraya
# 	sharp_kay
# 	big_hodgkin
# 	amazing_bartik
# 	golden_solvay
# 	voluminous_boyd
# 	condescending_plateau
# 	naughty_payne
# 	ecstatic_blackwell
# 	goofy_crick
# 	lonely_shirley
# 	sad_bohr
# 	infallible_goldberg
# 	prickly_majorana
# 	romantic_cuvier
# 	prickly_hawking
# 	romantic_picasso
# 	big_boltzmann
# 	nostalgic_swanson
# 	high_sax
# 	furious_cray
# 	high_raman
# 	nasty_fourier
# 	nasty_bell
# 	stupefied_gutenberg
# Checking inputs in folder known_extension
# Checking folder known_minimal
# 	happy_brenner
# 	nice_caravaggio
# 	zen_tuckerman
# 	adoring_mercator
# 	disturbed_lichterman
# 	peaceful_allen
# 	crazy_goodall
# 	intergalactic_lavoisier
# 	voluminous_gautier
# 	dreamy_golick
# 	lonely_ride
# 	reverent_lichterman
# 	sad_borg
# 	pensive_spence
# 	exotic_spence
# 	suspicious_mclean
# 	sick_snyder
# 	irreverent_bell
# 	cheesy_wing
# 	sharp_shaw
# 	magical_heisenberg
# 	hungry_yonath
# 	intergalactic_shaw
# 	exotic_mestorf
# 	trusting_stonebraker
# 	sleepy_koch
# 	intergalactic_moriondo
# 	romantic_ritchie
# 	evil_hilbert
# 	agitated_colden
# 	furious_pasteur
# 	cheeky_cajal
# 	thirsty_ptolemy
# 	ecstatic_woese
# 	gloomy_goldberg
# 	chaotic_gauss
# 	reverent_booth
# 	gigantic_shockley
# 	stupefied_swirles
# 	drunk_franklin
# 	berserk_bassi
# 	mad_angela
# 	distracted_fermi
# 	astonishing_albattani
# 	backstabbing_marconi
# 	thirsty_leakey
# 	determined_linnaeus
# 	intergalactic_jepsen
# 	cranky_kowalevski
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 30
#      28     missformedOutputs.loc[len(missformedOutputs)] = {"benchmark_set": benchmark_set, "prediction_name": prediction_name, "reason": "prediction folder does not exist"}
#      29     continue
# ---> 30 for model_file in [(p / "model.cif") for p in structureFolder.iterdir() if p.is_dir() and (p / "model.cif").exists()]:
#      31     model_seed = model_file.parent.name
#      32     if len(metricFile.loc[metricFile["model_id"] == model_seed, ["prediction_file"]]) == 0:
#
# File c:\Users\abril\dev\programs\minconda\envs\bachelor01\Lib\pathlib.py:860, in Path.exists(self, follow_symlinks)
#     853 """
#     854 Whether this path exists.
#     855
#     856 This method normally follows symlinks; to check whether a symlink exists,
#     857 add the argument follow_symlinks=False.
#     858 """
#     859 try:
# --> 860     self.stat(follow_symlinks=follow_symlinks)
#     861 except OSError as e:
#     862     if not _ignore_error(e):
#
# File c:\Users\abril\dev\programs\minconda\envs\bachelor01\Lib\pathlib.py:840, in Path.stat(self, follow_symlinks)
#     835 def stat(self, *, follow_symlinks=True):
#     836     """
#     837     Return the result of the stat() system call on this path, like
#     838     os.stat() does.
#     839     """
# --> 840     return os.stat(self, follow_symlinks=follow_symlinks)
#
# KeyboardInterrupt:

# %%
# Finding duplicates
duplicateOutputs = dataAF[dataAF.duplicated(subset=["prediction_name", "model_id"], keep=False)]

# %%
display(dataAF)
print("Missformed outputs")
display(missformedOutputs)
print("Missing outputs")
display(missingOutputs)
print("Empty outputs")
display(emptyOutputs)
print("Duplicate outputs")
display(duplicateOutputs)
# Out:
#      model_id  chainA_length  chainB_length  fraction_disordered  has_clash  \
# 0    ranked_1            300             85                 0.22        0.0
# 1    ranked_2            300             85                 0.22        0.0
# 2    ranked_3            300             85                 0.22        0.0
# 3    ranked_4            300             85                 0.22        0.0
# 4    ranked_5            300             85                 0.22        0.0
# ..        ...            ...            ...                  ...        ...
# 660  ranked_1            925            247                 0.06        0.0
# 661  ranked_2            925            247                 0.07        0.0
# 662  ranked_3            925            247                 0.06        0.0
# 663  ranked_4            925            247                 0.07        0.0
# 664  ranked_5            925            247                 0.06        0.0
#
#      iptm   ptm  ranking_score  chainA_intf_avg_plddt  chainB_intf_avg_plddt  \
# 0    0.65  0.75           0.78                  82.73                  56.47
# 1    0.64  0.74           0.77                  83.06                  35.59
# 2    0.62  0.76           0.76                  83.34                  51.20
# 3    0.60  0.76           0.74                  83.98                  49.64
# 4    0.53  0.75           0.69                  81.61                  56.76
# ..    ...   ...            ...                    ...                    ...
# 660  0.22  0.63           0.33                  47.19                  53.63
# 661  0.18  0.62           0.30                  48.34                  56.83
# 662  0.15  0.64           0.28                  47.39                  52.20
# 663  0.13  0.63           0.27                  72.69                  61.45
# 664  0.13  0.63           0.26                  70.38                  60.94
#
#      ...  num_chainB_intf_res  num_res_res_contact  num_atom_atom_contact  \
# 0    ...                    9                   38                    335
# 1    ...                   23                   69                    679
# 2    ...                   14                   38                    400
# 3    ...                   16                   48                    469
# 4    ...                   11                   35                    317
# ..   ...                  ...                  ...                    ...
# 660  ...                   59                  126                   1047
# 661  ...                  101                  307                   3339
# 662  ...                   33                   71                    698
# 663  ...                   16                   27                    141
# 664  ...                   32                   56                    418
#
#       iPAE  pDockQ  project_name                   prediction_name  \
# 0     6.10    0.08   sharp_woese  lig_lrp6_inhibitor_1_m1_m85_dmin
# 1    23.50    0.16   sharp_woese  lig_lrp6_inhibitor_1_m1_m85_dmin
# 2     4.40    0.12   sharp_woese  lig_lrp6_inhibitor_1_m1_m85_dmin
# 3     7.15    0.13   sharp_woese  lig_lrp6_inhibitor_1_m1_m85_dmin
# 4     4.90    0.10   sharp_woese  lig_lrp6_inhibitor_1_m1_m85_dmin
# ..     ...     ...           ...                               ...
# 660  27.90    0.15  furious_cray   lig_vh1_vbs_1_m494_m740_d1_d925
# 661  29.30    0.40  furious_cray   lig_vh1_vbs_1_m494_m740_d1_d925
# 662  28.90    0.07  furious_cray   lig_vh1_vbs_1_m494_m740_d1_d925
# 663  29.80    0.14  furious_cray   lig_vh1_vbs_1_m494_m740_d1_d925
# 664  30.20    0.38  furious_cray   lig_vh1_vbs_1_m494_m740_d1_d925
#
#     model_preset    benchmark_set  \
# 0     alphafold3  known_extension
# 1     alphafold3  known_extension
# 2     alphafold3  known_extension
# 3     alphafold3  known_extension
# 4     alphafold3  known_extension
# ..           ...              ...
# 660   alphafold3  known_extension
# 661   alphafold3  known_extension
# 662   alphafold3  known_extension
# 663   alphafold3  known_extension
# 664   alphafold3  known_extension
#
#                                        prediction_file
# 0    L:\imb-luckgr2\projects\AlphaFold\AlphaFold3\A...
# 1    L:\imb-luckgr2\projects\AlphaFold\AlphaFold3\A...
# 2    L:\imb-luckgr2\projects\AlphaFold\AlphaFold3\A...
# 3    L:\imb-luckgr2\projects\AlphaFold\AlphaFold3\A...
# 4    L:\imb-luckgr2\projects\AlphaFold\AlphaFold3\A...
# ..                                                 ...
# 660  L:\imb-luckgr2\projects\AlphaFold\AlphaFold3\A...
# 661  L:\imb-luckgr2\projects\AlphaFold\AlphaFold3\A...
# 662  L:\imb-luckgr2\projects\AlphaFold\AlphaFold3\A...
# 663  L:\imb-luckgr2\projects\AlphaFold\AlphaFold3\A...
# 664  L:\imb-luckgr2\projects\AlphaFold\AlphaFold3\A...
#
# [665 rows x 22 columns]
# Missformed outputs
# Empty DataFrame
# Columns: [benchmark_set, prediction_name, model_seed, reason]
# Index: []
# Missing outputs
#        benchmark_set                                    prediction_name
# 0    known_extension                        LIG_Pex14_3_M1_M412_D1_D377
# 1    known_extension            LIG_PDZ_Class_1_M1590_M1601_D1084_D1593
# 2    known_extension            LIG_PDZ_Class_1_M1590_M1601_D1185_D1492
# 3    known_extension                   LIG_PDZ_Class_1_M1590_M1601_Dmin
# 4    known_extension                   LIG_PDZ_Class_1_Mmin_D1084_D1593
# ..               ...                                                ...
# 969   random_minimal         MTRG_ER_FFAT_1_2RR3.DDOC_MAPK_HePTP_8_2GPH
# 970   random_minimal  MTRG_LysEnd_GGAAcLL_1_1JWG.DLIG_SUMO_SIM_anti_...
# 971   random_minimal       MTRG_NES_CRM1_1_3GB8.DDOC_PP1_MyPhoNE_1_1S70
# 972   random_minimal    MTRG_NLS_Bipartite_1_1PJM.DLIG_PDZ_Class_1_1D5G
# 973   random_minimal           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3
#
# [974 rows x 2 columns]
# Empty outputs
#      benchmark_set        nextflow_name
# 0  known_extension           sad_austin
# 1  known_extension      jolly_dalembert
# 2  known_extension    magical_boltzmann
# 3  known_extension            sharp_kay
# 4  known_extension    nostalgic_swanson
# 5  known_extension           high_raman
# 6  known_extension        nasty_fourier
# 7  known_extension           nasty_bell
# 8  known_extension  stupefied_gutenberg

# %%
input_count = len([f for f in outputFolders[0].iterdir() if f.is_file() and f.suffix.lower() == ".json"])
output_count = len(set(dataAF["prediction_name"]))
print(input_count, output_count)
# Out:
# 565 133

# %% [markdown]
# ## Scanning report.html

# %%
report_df = pd.DataFrame(columns=["benchmark_set", "report_file", "prediction_name", "ok"])
for outputFolder in outputFolders:
    print(f"Checking folder {outputFolder.name}")
    benchmark_set = outputFolder.name
    for p in [f for f in outputFolders[0].iterdir() if f.is_file() and "report" in f.stem and f.suffix.lower() == ".html"]:
        with open(p) as f:
            content = f.read()
        prediction_name = x.groups()[0] if (x := re.search(r"\(\[id:\[(\w+)\], jobsize:\d+\]\)", content)) is not None else None
        finished = ("Workflow execution completed successfully!" in content)
        print(f"\t{p.name}: {'' if prediction_name is None else prediction_name} ({'ok' if finished else 'failed'})")
        report_df.loc[len(report_df)] = {"benchmark_set": benchmark_set, "report_file": p.name, "prediction_name": prediction_name, "ok": finished}
report_df
# Out:
# report_2025-01-31_15-12.html
# report_2025-01-31_15-19.html
# report_2025-01-31_15-41.html
# report_2025-01-31_16-04.html
# report_2025-01-31_16-29.html
# report_2025-01-31_16-50.html
# report_2025-01-31_17-13.html
# report_2025-01-31_17-37.html
# report_2025-01-31_17-58.html
# report_2025-01-31_18-21.html
# report_2025-01-31_18-45.html
# report_2025-01-31_19-07.html
# report_2025-01-31_19-26.html
# report_2025-01-31_20-44.html
# report_2025-01-31_21-08.html
# report_2025-01-31_21-27.html
# report_2025-01-31_21-49.html
# report_2025-01-31_22-08.html
# report_2025-01-31_22-29.html
# report_2025-01-31_22-48.html
# report_2025-01-31_23-10.html
# report_2025-01-31_23-29.html
# report_2025-01-31_23-54.html
# report_2025-02-01_00-15.html
# report_2025-02-01_00-39.html
# report_2025-02-01_01-01.html
# report_2025-02-01_01-20.html
# report_2025-02-01_01-35.html
# report_2025-02-01_01-52.html
# report_2025-02-01_02-12.html
# report_2025-02-01_02-29.html
# report_2025-02-01_02-46.html
# report_2025-02-01_03-05.html
# report_2025-02-01_03-20.html
# report_2025-02-01_03-42.html
# report_2025-02-01_04-00.html
# report_2025-02-01_04-21.html
# report_2025-02-01_04-43.html
# report_2025-02-01_05-01.html
# report_2025-02-01_05-24.html
# report_2025-02-01_05-49.html
# report_2025-02-01_06-09.html
# report_2025-02-01_06-34.html
# report_2025-02-01_06-55.html
# report_2025-02-01_07-18.html
# report_2025-02-01_07-40.html
# report_2025-02-01_08-05.html
# report_2025-02-01_08-26.html
# report_2025-02-01_08-45.html
# report_2025-02-01_09-06.html
# report_2025-02-01_09-25.html
# report_2025-02-01_09-46.html
# report_2025-02-01_10-06.html
# report_2025-02-01_10-27.html
# report_2025-02-01_10-45.html
# report_2025-02-01_11-53.html
# report_2025-02-01_12-13.html
# report_2025-02-01_12-32.html
# report_2025-02-01_12-57.html
# report_2025-02-01_13-28.html
# report_2025-02-01_13-52.html
# report_2025-02-01_14-22.html
# report_2025-02-01_14-46.html
# report_2025-02-01_15-10.html
# report_2025-02-01_15-29.html
# report_2025-02-01_15-45.html
# report_2025-02-01_16-08.html
# report_2025-02-01_16-29.html
# report_2025-02-01_16-45.html
# report_2025-02-01_17-13.html
# report_2025-02-01_17-41.html
# report_2025-02-01_18-00.html
# report_2025-02-01_18-17.html
# report_2025-02-01_18-34.html
# report_2025-02-01_18-51.html
# report_2025-02-01_19-09.html
# report_2025-02-01_19-24.html
# report_2025-02-01_19-41.html
# report_2025-02-01_19-59.html
# report_2025-02-01_20-15.html
# report_2025-02-01_20-32.html
# report_2025-02-01_20-55.html
# report_2025-02-01_21-21.html
# report_2025-02-01_21-39.html
# report_2025-02-01_22-00.html
# report_2025-02-01_22-16.html
# report_2025-02-01_22-43.html
# report_2025-02-01_23-01.html
# report_2025-02-01_23-22.html
# report_2025-02-01_23-46.html
# report_2025-02-02_00-10.html
# report_2025-02-02_00-26.html
# report_2025-02-02_00-44.html
# report_2025-02-02_01-07.html
# report_2025-02-02_01-22.html
# report_2025-02-02_01-41.html
# report_2025-02-02_02-03.html
# report_2025-02-02_02-20.html
# report_2025-02-02_02-41.html
# report_2025-02-02_03-08.html
# report_2025-02-02_03-29.html
# report_2025-02-02_03-50.html
# report_2025-02-02_04-08.html
# report_2025-02-02_04-31.html
# report_2025-02-02_04-54.html
# report_2025-02-02_05-12.html
# report_2025-02-02_05-29.html
# report_2025-02-02_05-48.html
# report_2025-02-02_06-06.html
# report_2025-02-02_06-22.html
# report_2025-02-02_06-42.html
# report_2025-02-02_06-58.html
# report_2025-02-02_07-15.html
# report_2025-02-02_07-35.html
# report_2025-02-02_07-51.html
# report_2025-02-02_08-08.html
# report_2025-02-02_08-28.html
# report_2025-02-02_08-44.html
# report_2025-02-02_09-00.html
# report_2025-02-02_15-35.html
# report_2025-02-02_16-20.html
# report_2025-02-02_17-03.html
# report_2025-02-02_17-48.html
# report_2025-02-02_18-28.html
# report_2025-02-02_19-08.html
# report_2025-02-02_19-53.html
# report_2025-02-02_20-33.html
# report_2025-02-02_21-13.html
# report_2025-02-02_21-54.html
# report_2025-02-02_22-50.html
# report_2025-02-02_23-21.html
# report_2025-02-02_23-52.html
# report_2025-02-03_00-34.html
# report_2025-02-03_01-16.html
# report_2025-02-03_03-31.html
# report_2025-02-03_04-53.html
# report_2025-02-03_09-50.html
# report_2025-02-03_14-47.html
# report_2025-02-03_15-34.html
# report_2025-02-03_15-49.html
# report_2025-01-31_15-12.html
# report_2025-01-31_15-19.html
# report_2025-01-31_15-41.html
# report_2025-01-31_16-04.html
# report_2025-01-31_16-29.html
# report_2025-01-31_16-50.html
# report_2025-01-31_17-13.html
# report_2025-01-31_17-37.html
# report_2025-01-31_17-58.html
# report_2025-01-31_18-21.html
# report_2025-01-31_18-45.html
# report_2025-01-31_19-07.html
# report_2025-01-31_19-26.html
# report_2025-01-31_20-44.html
# report_2025-01-31_21-08.html
# report_2025-01-31_21-27.html
# report_2025-01-31_21-49.html
# report_2025-01-31_22-08.html
# report_2025-01-31_22-29.html
# report_2025-01-31_22-48.html
# report_2025-01-31_23-10.html
# report_2025-01-31_23-29.html
# report_2025-01-31_23-54.html
# report_2025-02-01_00-15.html
# report_2025-02-01_00-39.html
# report_2025-02-01_01-01.html
# report_2025-02-01_01-20.html
# report_2025-02-01_01-35.html
# report_2025-02-01_01-52.html
# report_2025-02-01_02-12.html
# report_2025-02-01_02-29.html
# report_2025-02-01_02-46.html
# report_2025-02-01_03-05.html
# report_2025-02-01_03-20.html
# report_2025-02-01_03-42.html
# report_2025-02-01_04-00.html
# report_2025-02-01_04-21.html
# report_2025-02-01_04-43.html
# report_2025-02-01_05-01.html
# report_2025-02-01_05-24.html
# report_2025-02-01_05-49.html
# report_2025-02-01_06-09.html
# report_2025-02-01_06-34.html
# report_2025-02-01_06-55.html
# report_2025-02-01_07-18.html
# report_2025-02-01_07-40.html
# report_2025-02-01_08-05.html
# report_2025-02-01_08-26.html
# report_2025-02-01_08-45.html
# report_2025-02-01_09-06.html
# report_2025-02-01_09-25.html
# report_2025-02-01_09-46.html
# report_2025-02-01_10-06.html
# report_2025-02-01_10-27.html
# report_2025-02-01_10-45.html
# report_2025-02-01_11-53.html
# report_2025-02-01_12-13.html
# report_2025-02-01_12-32.html
# report_2025-02-01_12-57.html
# report_2025-02-01_13-28.html
# report_2025-02-01_13-52.html
# report_2025-02-01_14-22.html
# report_2025-02-01_14-46.html
# report_2025-02-01_15-10.html
# report_2025-02-01_15-29.html
# report_2025-02-01_15-45.html
# report_2025-02-01_16-08.html
# report_2025-02-01_16-29.html
# report_2025-02-01_16-45.html
# report_2025-02-01_17-13.html
# report_2025-02-01_17-41.html
# report_2025-02-01_18-00.html
# report_2025-02-01_18-17.html
# report_2025-02-01_18-34.html
# report_2025-02-01_18-51.html
# report_2025-02-01_19-09.html
# report_2025-02-01_19-24.html
# report_2025-02-01_19-41.html
# report_2025-02-01_19-59.html
# report_2025-02-01_20-15.html
# report_2025-02-01_20-32.html
# report_2025-02-01_20-55.html
# report_2025-02-01_21-21.html
# report_2025-02-01_21-39.html
# report_2025-02-01_22-00.html
# report_2025-02-01_22-16.html
# report_2025-02-01_22-43.html
# report_2025-02-01_23-01.html
# report_2025-02-01_23-22.html
# report_2025-02-01_23-46.html
# report_2025-02-02_00-10.html
# report_2025-02-02_00-26.html
# report_2025-02-02_00-44.html
# report_2025-02-02_01-07.html
# report_2025-02-02_01-22.html
# report_2025-02-02_01-41.html
# report_2025-02-02_02-03.html
# report_2025-02-02_02-20.html
# report_2025-02-02_02-41.html
# report_2025-02-02_03-08.html
# report_2025-02-02_03-29.html
# report_2025-02-02_03-50.html
# report_2025-02-02_04-08.html
# report_2025-02-02_04-31.html
# report_2025-02-02_04-54.html
# report_2025-02-02_05-12.html
# report_2025-02-02_05-29.html
# report_2025-02-02_05-48.html
# report_2025-02-02_06-06.html
# report_2025-02-02_06-22.html
# report_2025-02-02_06-42.html
# report_2025-02-02_06-58.html
# report_2025-02-02_07-15.html
# report_2025-02-02_07-35.html
# report_2025-02-02_07-51.html
# report_2025-02-02_08-08.html
# report_2025-02-02_08-28.html
# report_2025-02-02_08-44.html
# report_2025-02-02_09-00.html
# report_2025-02-02_15-35.html
# report_2025-02-02_16-20.html
# report_2025-02-02_17-03.html
# report_2025-02-02_17-48.html
# report_2025-02-02_18-28.html
# report_2025-02-02_19-08.html
# report_2025-02-02_19-53.html
# report_2025-02-02_20-33.html
# report_2025-02-02_21-13.html
# report_2025-02-02_21-54.html
# report_2025-02-02_22-50.html
# report_2025-02-02_23-21.html
# report_2025-02-02_23-52.html
# report_2025-02-03_00-34.html
# report_2025-02-03_01-16.html
# report_2025-02-03_03-31.html
# report_2025-02-03_04-53.html
# report_2025-02-03_09-50.html
# report_2025-02-03_14-47.html
# report_2025-02-03_15-34.html
# report_2025-02-03_15-49.html
# report_2025-01-31_15-12.html
# report_2025-01-31_15-19.html
# report_2025-01-31_15-41.html
# report_2025-01-31_16-04.html
# report_2025-01-31_16-29.html
# report_2025-01-31_16-50.html
# report_2025-01-31_17-13.html
# report_2025-01-31_17-37.html
# report_2025-01-31_17-58.html
# report_2025-01-31_18-21.html
# report_2025-01-31_18-45.html
# report_2025-01-31_19-07.html
# report_2025-01-31_19-26.html
# report_2025-01-31_20-44.html
# report_2025-01-31_21-08.html
# report_2025-01-31_21-27.html
# report_2025-01-31_21-49.html
# report_2025-01-31_22-08.html
# report_2025-01-31_22-29.html
# report_2025-01-31_22-48.html
# report_2025-01-31_23-10.html
# report_2025-01-31_23-29.html
# report_2025-01-31_23-54.html
# report_2025-02-01_00-15.html
# report_2025-02-01_00-39.html
# report_2025-02-01_01-01.html
# report_2025-02-01_01-20.html
# report_2025-02-01_01-35.html
# report_2025-02-01_01-52.html
# report_2025-02-01_02-12.html
# report_2025-02-01_02-29.html
# report_2025-02-01_02-46.html
# report_2025-02-01_03-05.html
# report_2025-02-01_03-20.html
# report_2025-02-01_03-42.html
# report_2025-02-01_04-00.html
# report_2025-02-01_04-21.html
# report_2025-02-01_04-43.html
# report_2025-02-01_05-01.html
# report_2025-02-01_05-24.html
# report_2025-02-01_05-49.html
# report_2025-02-01_06-09.html
# report_2025-02-01_06-34.html
# report_2025-02-01_06-55.html
# report_2025-02-01_07-18.html
# report_2025-02-01_07-40.html
# report_2025-02-01_08-05.html
# report_2025-02-01_08-26.html
# report_2025-02-01_08-45.html
# report_2025-02-01_09-06.html
# report_2025-02-01_09-25.html
# report_2025-02-01_09-46.html
# report_2025-02-01_10-06.html
# report_2025-02-01_10-27.html
# report_2025-02-01_10-45.html
# report_2025-02-01_11-53.html
# report_2025-02-01_12-13.html
# report_2025-02-01_12-32.html
# report_2025-02-01_12-57.html
# report_2025-02-01_13-28.html
# report_2025-02-01_13-52.html
# report_2025-02-01_14-22.html
# report_2025-02-01_14-46.html
# report_2025-02-01_15-10.html
# report_2025-02-01_15-29.html
# report_2025-02-01_15-45.html
# report_2025-02-01_16-08.html
# report_2025-02-01_16-29.html
# report_2025-02-01_16-45.html
# report_2025-02-01_17-13.html
# report_2025-02-01_17-41.html
# report_2025-02-01_18-00.html
# report_2025-02-01_18-17.html
# report_2025-02-01_18-34.html
# report_2025-02-01_18-51.html
# report_2025-02-01_19-09.html
# report_2025-02-01_19-24.html
# report_2025-02-01_19-41.html
# report_2025-02-01_19-59.html
# report_2025-02-01_20-15.html
# report_2025-02-01_20-32.html
# report_2025-02-01_20-55.html
# report_2025-02-01_21-21.html
# report_2025-02-01_21-39.html
# report_2025-02-01_22-00.html
# report_2025-02-01_22-16.html
# report_2025-02-01_22-43.html
# report_2025-02-01_23-01.html
# report_2025-02-01_23-22.html
# report_2025-02-01_23-46.html
# report_2025-02-02_00-10.html
# report_2025-02-02_00-26.html
# report_2025-02-02_00-44.html
# report_2025-02-02_01-07.html
# report_2025-02-02_01-22.html
# report_2025-02-02_01-41.html
# report_2025-02-02_02-03.html
# report_2025-02-02_02-20.html
# report_2025-02-02_02-41.html
# report_2025-02-02_03-08.html
# report_2025-02-02_03-29.html
# report_2025-02-02_03-50.html
# report_2025-02-02_04-08.html
# report_2025-02-02_04-31.html
# report_2025-02-02_04-54.html
# report_2025-02-02_05-12.html
# report_2025-02-02_05-29.html
# report_2025-02-02_05-48.html
# report_2025-02-02_06-06.html
# report_2025-02-02_06-22.html
# report_2025-02-02_06-42.html
# report_2025-02-02_06-58.html
# report_2025-02-02_07-15.html
# report_2025-02-02_07-35.html
# report_2025-02-02_07-51.html
# report_2025-02-02_08-08.html
# report_2025-02-02_08-28.html
# report_2025-02-02_08-44.html
# report_2025-02-02_09-00.html
# report_2025-02-02_15-35.html
# report_2025-02-02_16-20.html
# report_2025-02-02_17-03.html
# report_2025-02-02_17-48.html
# report_2025-02-02_18-28.html
# report_2025-02-02_19-08.html
# report_2025-02-02_19-53.html
# report_2025-02-02_20-33.html
# report_2025-02-02_21-13.html
# report_2025-02-02_21-54.html
# report_2025-02-02_22-50.html
# report_2025-02-02_23-21.html
# report_2025-02-02_23-52.html
# report_2025-02-03_00-34.html
# report_2025-02-03_01-16.html
# report_2025-02-03_03-31.html
# report_2025-02-03_04-53.html
# report_2025-02-03_09-50.html
# report_2025-02-03_14-47.html
# report_2025-02-03_15-34.html
# report_2025-02-03_15-49.html
# report_2025-01-31_15-12.html
# report_2025-01-31_15-19.html
# report_2025-01-31_15-41.html
# report_2025-01-31_16-04.html
# report_2025-01-31_16-29.html
# report_2025-01-31_16-50.html
# report_2025-01-31_17-13.html
# report_2025-01-31_17-37.html
# report_2025-01-31_17-58.html
# report_2025-01-31_18-21.html
# report_2025-01-31_18-45.html
# report_2025-01-31_19-07.html
# report_2025-01-31_19-26.html
# report_2025-01-31_20-44.html
# report_2025-01-31_21-08.html
# report_2025-01-31_21-27.html
# report_2025-01-31_21-49.html
# report_2025-01-31_22-08.html
# report_2025-01-31_22-29.html
# report_2025-01-31_22-48.html
# report_2025-01-31_23-10.html
# report_2025-01-31_23-29.html
# report_2025-01-31_23-54.html
# report_2025-02-01_00-15.html
# report_2025-02-01_00-39.html
# report_2025-02-01_01-01.html
# report_2025-02-01_01-20.html
# report_2025-02-01_01-35.html
# report_2025-02-01_01-52.html
# report_2025-02-01_02-12.html
# report_2025-02-01_02-29.html
# report_2025-02-01_02-46.html
# report_2025-02-01_03-05.html
# report_2025-02-01_03-20.html
# report_2025-02-01_03-42.html
# report_2025-02-01_04-00.html
# report_2025-02-01_04-21.html
# report_2025-02-01_04-43.html
# report_2025-02-01_05-01.html
# report_2025-02-01_05-24.html
# report_2025-02-01_05-49.html
# report_2025-02-01_06-09.html
# report_2025-02-01_06-34.html
# report_2025-02-01_06-55.html
# report_2025-02-01_07-18.html
# report_2025-02-01_07-40.html
# report_2025-02-01_08-05.html
# report_2025-02-01_08-26.html
# report_2025-02-01_08-45.html
# report_2025-02-01_09-06.html
# report_2025-02-01_09-25.html
# report_2025-02-01_09-46.html
# report_2025-02-01_10-06.html
# report_2025-02-01_10-27.html
# report_2025-02-01_10-45.html
# report_2025-02-01_11-53.html
# report_2025-02-01_12-13.html
# report_2025-02-01_12-32.html
# report_2025-02-01_12-57.html
# report_2025-02-01_13-28.html
# report_2025-02-01_13-52.html
# report_2025-02-01_14-22.html
# report_2025-02-01_14-46.html
# report_2025-02-01_15-10.html
# report_2025-02-01_15-29.html
# report_2025-02-01_15-45.html
# report_2025-02-01_16-08.html
# report_2025-02-01_16-29.html
# report_2025-02-01_16-45.html
# report_2025-02-01_17-13.html
# report_2025-02-01_17-41.html
# report_2025-02-01_18-00.html
# report_2025-02-01_18-17.html
# report_2025-02-01_18-34.html
# report_2025-02-01_18-51.html
# report_2025-02-01_19-09.html
# report_2025-02-01_19-24.html
# report_2025-02-01_19-41.html
# report_2025-02-01_19-59.html
# report_2025-02-01_20-15.html
# report_2025-02-01_20-32.html
# report_2025-02-01_20-55.html
# report_2025-02-01_21-21.html
# report_2025-02-01_21-39.html
# report_2025-02-01_22-00.html
# report_2025-02-01_22-16.html
# report_2025-02-01_22-43.html
# report_2025-02-01_23-01.html
# report_2025-02-01_23-22.html
# report_2025-02-01_23-46.html
# report_2025-02-02_00-10.html
# report_2025-02-02_00-26.html
# report_2025-02-02_00-44.html
# report_2025-02-02_01-07.html
# report_2025-02-02_01-22.html
# report_2025-02-02_01-41.html
# report_2025-02-02_02-03.html
# report_2025-02-02_02-20.html
# report_2025-02-02_02-41.html
# report_2025-02-02_03-08.html
# report_2025-02-02_03-29.html
# report_2025-02-02_03-50.html
# report_2025-02-02_04-08.html
# report_2025-02-02_04-31.html
# report_2025-02-02_04-54.html
# report_2025-02-02_05-12.html
# report_2025-02-02_05-29.html
# report_2025-02-02_05-48.html
# report_2025-02-02_06-06.html
# report_2025-02-02_06-22.html
# report_2025-02-02_06-42.html
# report_2025-02-02_06-58.html
# report_2025-02-02_07-15.html
# report_2025-02-02_07-35.html
# report_2025-02-02_07-51.html
# report_2025-02-02_08-08.html
# report_2025-02-02_08-28.html
# report_2025-02-02_08-44.html
# report_2025-02-02_09-00.html
# report_2025-02-02_15-35.html
# report_2025-02-02_16-20.html
# report_2025-02-02_17-03.html
# report_2025-02-02_17-48.html
# report_2025-02-02_18-28.html
# report_2025-02-02_19-08.html
# report_2025-02-02_19-53.html
# report_2025-02-02_20-33.html
# report_2025-02-02_21-13.html
# report_2025-02-02_21-54.html
# report_2025-02-02_22-50.html
# report_2025-02-02_23-21.html
# report_2025-02-02_23-52.html
# report_2025-02-03_00-34.html
# report_2025-02-03_01-16.html
# report_2025-02-03_03-31.html
# report_2025-02-03_04-53.html
# report_2025-02-03_09-50.html
# report_2025-02-03_14-47.html
# report_2025-02-03_15-34.html
# report_2025-02-03_15-49.html
#        benchmark_set                   report_file  \
# 0    known_extension  report_2025-01-31_15-12.html
# 1    known_extension  report_2025-01-31_15-19.html
# 2    known_extension  report_2025-01-31_15-41.html
# 3    known_extension  report_2025-01-31_16-04.html
# 4    known_extension  report_2025-01-31_16-29.html
# ..               ...                           ...
# 555   random_minimal  report_2025-02-03_04-53.html
# 556   random_minimal  report_2025-02-03_09-50.html
# 557   random_minimal  report_2025-02-03_14-47.html
# 558   random_minimal  report_2025-02-03_15-34.html
# 559   random_minimal  report_2025-02-03_15-49.html
#
#                              prediction_name     ok
# 0                                       None  False
# 1           LIG_LRP6_Inhibitor_1_M1_M85_Dmin   True
# 2       LIG_LRP6_Inhibitor_1_M23_M57_D1_D362   True
# 3       LIG_LRP6_Inhibitor_1_M23_M57_D1_D422   True
# 4          LIG_LRP6_Inhibitor_1_M23_M57_Dmin   True
# ..                                       ...    ...
# 555                   LIG_Vh1_VBS_1_MFL_Dmin  False
# 556         LIG_Vh1_VBS_1_M196_M1983_D1_D925   True
# 557          LIG_Vh1_VBS_1_M494_M740_D1_D925   True
# 558          LIG_Vh1_VBS_1_M532_M702_D1_D925  False
# 559  LIG_PDZ_Class_1_M1590_M1601_D1084_D1593  False
#
# [560 rows x 4 columns]

# %%
report_df
# Out:
#        benchmark_set                   report_file  \
# 0    known_extension  report_2025-01-31_15-12.html
# 1    known_extension  report_2025-01-31_15-19.html
# 2    known_extension  report_2025-01-31_15-41.html
# 3    known_extension  report_2025-01-31_16-04.html
# 4    known_extension  report_2025-01-31_16-29.html
# ..               ...                           ...
# 555   random_minimal  report_2025-02-03_04-53.html
# 556   random_minimal  report_2025-02-03_09-50.html
# 557   random_minimal  report_2025-02-03_14-47.html
# 558   random_minimal  report_2025-02-03_15-34.html
# 559   random_minimal  report_2025-02-03_15-49.html
#
#                              prediction_name     ok
# 0                                       None  False
# 1           LIG_LRP6_Inhibitor_1_M1_M85_Dmin   True
# 2       LIG_LRP6_Inhibitor_1_M23_M57_D1_D362   True
# 3       LIG_LRP6_Inhibitor_1_M23_M57_D1_D422   True
# 4          LIG_LRP6_Inhibitor_1_M23_M57_Dmin   True
# ..                                       ...    ...
# 555                   LIG_Vh1_VBS_1_MFL_Dmin  False
# 556         LIG_Vh1_VBS_1_M196_M1983_D1_D925   True
# 557          LIG_Vh1_VBS_1_M494_M740_D1_D925   True
# 558          LIG_Vh1_VBS_1_M532_M702_D1_D925  False
# 559  LIG_PDZ_Class_1_M1590_M1601_D1084_D1593  False
#
# [560 rows x 4 columns]
