# %% [markdown]
# # Plotting the measurements of the dataset
# Created 2025-01-07 based on a file from 2024-12-19

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# %%
dataAF = pd.read_csv(Path("../ressources//af_structures.csv"))
dataSolved = pd.read_csv(Path("../ressources//solved_structures.csv"))
predictionAF = pd.read_excel(Path("../ressources/ISS AF_DMI_structures/AF_prediction_randomized_DMI_results.xlsx"))

predictionAF["model_id"] = predictionAF["model_id"] + ".pdb"

_dataAF = pd.merge(
    left=dataAF, 
    right=predictionAF,
    how='left',
    left_on=['structure_name', 'file'],
    right_on=['prediction_name', 'model_id'],
)
_dataAF["num_mutation_in_motif"] = _dataAF["num_mutation_in_motif"].replace({np.nan: "Unkown"})
_dataAF["num_mutation_in_motif"] = _dataAF["num_mutation_in_motif"].replace({"known minimal": "Positive"})
_dataAF["num_mutation_in_motif"] = _dataAF["num_mutation_in_motif"].replace({"random minimal": "Negative"})
dataAF = _dataAF[[*dataAF.columns, "num_mutation_in_motif"]]
print("Unique values in num_mutation_in_motif:", set(dataAF["num_mutation_in_motif"]))
# Out:
# Unique values in num_mutation_in_motif: {'Unkown', 'Positive', 'Negative'}

# %%
dataAF
# Out:
#               structure_name          file  hbonds  salt_bridges  buried_area  \
# 0     DEG_APCC_KENBOX_2_4GGD  ranked_0.pdb       9             0      613.651
# 1     DEG_APCC_KENBOX_2_4GGD  ranked_1.pdb       9             0      580.310
# 2     DEG_APCC_KENBOX_2_4GGD  ranked_2.pdb      10             0      662.104
# 3     DEG_APCC_KENBOX_2_4GGD  ranked_3.pdb       2             0      398.498
# 4     DEG_APCC_KENBOX_2_4GGD  ranked_4.pdb       2             0      323.304
# ...                      ...           ...     ...           ...          ...
# 1337           TRG_PTS1_2C0L  ranked_0.pdb      12             3      883.012
# 1338           TRG_PTS1_2C0L  ranked_1.pdb      11             3      889.343
# 1339           TRG_PTS1_2C0L  ranked_2.pdb      12             3      890.493
# 1340           TRG_PTS1_2C0L  ranked_3.pdb      11             3      894.777
# 1341           TRG_PTS1_2C0L  ranked_4.pdb      12             3      888.589
#
#       min_distance  hydrophobic_interactions num_mutation_in_motif
# 0            6.063                         0              Positive
# 1            6.083                         0              Positive
# 2            6.072                         3              Positive
# 3            5.417                         0              Positive
# 4            5.092                         9              Positive
# ...            ...                       ...                   ...
# 1337         4.542                        29              Positive
# 1338         4.559                        29              Positive
# 1339         4.574                        30              Positive
# 1340         4.529                        30              Positive
# 1341         4.568                        27              Positive
#
# [1342 rows x 8 columns]

# %%
dataSolved
# Out:
#     structure_name              file  hbonds  salt_bridges  buried_area  \
# 0     1ATP_min_DMI  1ATP_min_DMI.pdb       1             0      808.592
# 1     1AXC_min_DMI  1AXC_min_DMI.pdb       4             0     1209.332
# 2     1B72_min_DMI  1B72_min_DMI.pdb       1             0      547.149
# 3     1B8Q_min_DMI  1B8Q_min_DMI.pdb       4             0      871.756
# 4     1BXX_min_DMI  1BXX_min_DMI.pdb       6             0      783.465
# ..             ...               ...     ...           ...          ...
# 133   5MLW_min_DMI  5MLW_min_DMI.pdb       2             0      960.870
# 134   5VZU_min_DMI  5VZU_min_DMI.pdb       4             0      868.375
# 135   6FUZ_min_DMI  6FUZ_min_DMI.pdb      10             3     1081.201
# 136   6G84_min_DMI  6G84_min_DMI.pdb       4             0     1146.941
# 137   7DS2_min_DMI  7DS2_min_DMI.pdb       8             6     1506.106
#
#      min_distance  hydrophobic_interactions
# 0           6.273                        77
# 1           4.174                        62
# 2           5.182                        36
# 3           4.376                        42
# 4           4.435                        19
# ..            ...                       ...
# 133         4.282                       114
# 134         4.959                        33
# 135         5.532                         2
# 136         5.521                        35
# 137         5.075                        51
#
# [138 rows x 7 columns]

# %%
predictionAF
# Out:
#               prediction_name  chainA_length  chainB_length      model_id  \
# 0      DEG_APCC_KENBOX_2_4GGD            312              5  ranked_0.pdb
# 1      DEG_APCC_KENBOX_2_4GGD            312              5  ranked_1.pdb
# 2      DEG_APCC_KENBOX_2_4GGD            312              5  ranked_2.pdb
# 3      DEG_APCC_KENBOX_2_4GGD            312              5  ranked_3.pdb
# 4      DEG_APCC_KENBOX_2_4GGD            312              5  ranked_4.pdb
# ...                       ...            ...            ...           ...
# 2695  TRG_PTS1_2C0L_NAKL.NAKD            305              4  ranked_0.pdb
# 2696  TRG_PTS1_2C0L_NAKL.NAKD            305              4  ranked_1.pdb
# 2697  TRG_PTS1_2C0L_NAKL.NAKD            305              4  ranked_2.pdb
# 2698  TRG_PTS1_2C0L_NAKL.NAKD            305              4  ranked_3.pdb
# 2699  TRG_PTS1_2C0L_NAKL.NAKD            305              4  ranked_4.pdb
#
#       model_confidence  chainA_intf_avg_plddt  chainB_intf_avg_plddt  \
# 0             0.887117              96.107999              77.495999
# 1             0.871984              95.793846              73.986000
# 2             0.760784              95.547501              57.906001
# 3             0.413662              94.646667              21.510000
# 4             0.359078              94.830001              19.753333
# ...                ...                    ...                    ...
# 2695          0.877999              96.388571              74.585001
# 2696          0.868754              96.614545              75.270000
# 2697          0.852158              96.452917              75.197498
# 2698          0.819368              95.764286              69.147499
# 2699          0.790574              95.154999              64.405001
#
#       intf_avg_plddt    pDockQ       iPAE  num_chainA_intf_res  \
# 0          91.454999  0.162263   3.311542                   15
# 1          89.736111  0.145001   3.395909                   13
# 2          86.585239  0.116743   6.166772                   16
# 3          76.362500  0.036380  16.713730                    9
# 4          72.307001  0.029969  18.696838                    7
# ...              ...       ...        ...                  ...
# 2695       92.900000  0.234389   2.903771                   21
# 2696       93.330769  0.233830   3.026700                   22
# 2697       93.416428  0.223745   3.121255                   24
# 2698       91.505600  0.204897   4.233161                   21
# 2699       90.029999  0.181055   4.798036                   20
#
#       num_chainB_intf_res  num_res_res_contact  num_atom_atom_contact  \
# 0                       5                   23                    208
# 1                       5                   20                    190
# 2                       5                   27                    237
# 3                       3                   11                     83
# 4                       3                    9                    108
# ...                   ...                  ...                    ...
# 2695                    4                   31                    271
# 2696                    4                   31                    262
# 2697                    4                   35                    272
# 2698                    4                   31                    258
# 2699                    4                   30                    235
#
#      num_mutation_in_motif  label
# 0            known minimal      1
# 1            known minimal      1
# 2            known minimal      1
# 3            known minimal      1
# 4            known minimal      1
# ...                    ...    ...
# 2695                     1      0
# 2696                     1      0
# 2697                     1      0
# 2698                     1      0
# 2699                     1      0
#
# [2700 rows x 16 columns]

# %%
def plotCummulative(column, title, ylabel, xlabel):
    plt.title(title)
    d = dataAF[column]
    d = d[~np.isnan(d)]
    plt.ecdf(d, color="green")
    #plt.vlines(np.median(d), ymin=0, ymax=1, label="median", colors="green", linestyles="dashed")
    plt.vlines(np.mean(d), ymin=0, ymax=1, label="mean AF", colors="green", linestyles="dotted")
    d = dataSolved[column]
    plt.ecdf(d, color="orange")
    #plt.vlines(np.median(d), ymin=0, ymax=1, label="median", colors="orange", linestyles="dashed")
    plt.vlines(np.mean(d), ymin=0, ymax=1, label="mean Solved", colors="orange", linestyles="dotted")
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.legend()
    plt.show()
plotCummulative("hbonds", "hydrogen bonds", "cummulative percentile", "count of hydrogen bonds")
plotCummulative("salt_bridges", "salt bridges", "cummulative percentile", "count of hydrogen bonds")
plotCummulative("buried_area", "surface area", "cummulative percentile", "area [Å²]")
plotCummulative("min_distance", "minimum interface distance ", "cummulative percentile", "distance [Å]")
plotCummulative("hydrophobic_interactions", "hydrophobic interactions", "cummulative percentile", "count")

# %%
def plotCummulative(column, title, ylabel, xlabel):
    fig, axes = plt.subplots(1, 2)
    fig.set_figwidth(13)
    for i, d in enumerate([dataAF[column], dataSolved[column]]):
        ax = axes[i]
        ax.set_title(title)
        ax.ecdf(d)
        ax.vlines(np.median(d), ymin=0, ymax=1, label="median", colors="grey", linestyles="dashed")
        ax.vlines(np.mean(d), ymin=0, ymax=1, label="mean", colors="grey", linestyles="dotted")
        ax.set_ylabel(ylabel)
        ax.set_xlabel(xlabel)
        ax.legend()
    plt.show()

# %%
plotCummulative("hbonds", "hydrogen bonds", "cummulative percentile", "count of hydrogen bonds")

# %%
d = data["hbonds"]
plt.title("hydrogen bonds")
plt.ecdf(d)
plt.vlines(np.median(d), ymin=0, ymax=1, label="median", colors="grey", linestyles="dashed")
plt.vlines(np.mean(d), ymin=0, ymax=1, label="mean", colors="grey", linestyles="dotted")
plt.ylabel("cummulative percentile")
plt.xlabel("count")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 d = data["hbonds"]
#       2 plt.title("hydrogen bonds")
#       3 plt.ecdf(d)
#
# NameError: name 'data' is not defined

# %%
d = data["salt_bridges"]
plt.title("salt bridges")
plt.ecdf(d)
plt.vlines(np.median(d), ymin=0, ymax=1, label="median", colors="grey", linestyles="dashed")
plt.vlines(np.mean(d), ymin=0, ymax=1, label="mean", colors="grey", linestyles="dotted")
plt.ylabel("cummulative percentile")
plt.xlabel("count")
plt.legend()
plt.show()

# %%
d = data["buried_area"]
plt.title("surface area")
plt.ecdf(d)
plt.vlines(np.median(d), ymin=0, ymax=1, label="median", colors="grey", linestyles="dashed")
plt.vlines(np.mean(d), ymin=0, ymax=1, label="mean", colors="grey", linestyles="dotted")
plt.ylabel("cummulative percentile")
plt.xlabel("area [Å²]")
plt.legend()
plt.show()

# %%
d = data["min_distance"]
plt.title("minimum interface distance")
plt.ecdf(d)
plt.vlines(np.median(d), ymin=0, ymax=1, label="median", colors="grey", linestyles="dashed")
plt.vlines(np.mean(d), ymin=0, ymax=1, label="mean", colors="grey", linestyles="dotted")
plt.ylabel("cummulative percentile")
plt.xlabel("distance [Å]")
plt.legend()
plt.show()

# %%
d = data["hydrophobic_interactions"]
plt.title("hydrophobic interactions")
plt.ecdf(d)
plt.vlines(np.median(d), ymin=0, ymax=1, label="median", colors="grey", linestyles="dashed")
plt.vlines(np.mean(d), ymin=0, ymax=1, label="mean", colors="grey", linestyles="dotted")
plt.ylabel("cummulative percentile")
plt.xlabel("count")
plt.legend()
plt.show()
